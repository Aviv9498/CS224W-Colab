# %% [markdown]
# <a href="https://colab.research.google.com/github/Aviv9498/CS224W-Colab/blob/main/CS224W_Colab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CS224W - Colab 5**

# %% [markdown]
# In this Colab we will experiment on scaling up GNNs using PyTorch Geometric, DeepSNAP and NetworkX. As we have **canceled** the Colab 5 assignment, this notebook will be a tutorial and you do not need to submit it on Gradescope.
#
# At first, we will use PyTorch Geometric `NeighborSampler` to scale up the training and testing on OGB `arxiv` dataset.
#
# Then, using the DeepSNAP and NetworkX, we will implement a simplified version of `NeighborSampler` and run experiments with different smapling ratios on the Cora graph.
#
# At last, we will partition the Cora graph into clusters by using different partition algorithms and then train the models in the way of vanilla Cluster-GCN.
#
# **Note**: Make sure to **sequentially run all the cells in each section**, so that the intermediate variables / packages will carry over to the next cell

# %% [markdown]
# # Device
# You might need to use GPU for this Colab.
#
# Please click `Runtime` and then `Change runtime type`. Then set the `hardware accelerator` to **GPU**.

# %% [markdown]
# # Installation

# %%
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-geometric
# !pip install -q ogb
# !pip install -q git+https://github.com/snap-stanford/deepsnap.git
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for torch-scatter (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for torch-sparse (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for littleutils (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for deepsnap (setup.py) ... done

# %%
import torch_geometric
torch_geometric.__version__
# Out:
# '2.4.0'

# %% [markdown]
# # 1 PyTorch Geometric Neighbor Sampling
#
# Neighbor Sampling, originally proposed in **GraphSAGE** ([Hamilton et al. (2017)](https://arxiv.org/abs/1706.02216)), is a representative method to scale up GNNs. As what we have learned in lecture, only a K-hop neighborhood nodes will be loaded into GPU for each time training. To further reduce the cost, we can sample a subset of neighborhood nodes for GNNs to aggregate.

# %% [markdown]
# ## Setup

# %%
import copy
import torch
import torch.nn.functional as F
import torch_geometric.transforms as T

from torch_geometric.nn import SAGEConv
from torch_geometric.data import NeighborSampler
from ogb.nodeproppred import PygNodePropPredDataset, Evaluator

# %% [markdown]
# ## Neighbor Sampler
#
# PyTorch Geometric has implemented the Neighbor Sampling method as the [NeighborSampler](https://pytorch-geometric.readthedocs.io/en/latest/modules/data.html#torch_geometric.data.NeighborSampler) in `torch_geometric.data`. Following is an example that uses the Neighbor Sampling method on training the OGB `arxiv` dataset.
#
# If you are interested in memory-efficient aggregations, please refer to PyG's [Memory-Efficient Aggregations](https://pytorch-geometric.readthedocs.io/en/latest/notes/sparse_tensor.html).

# %%
dataset_name = 'ogbn-arxiv'
dataset = PygNodePropPredDataset(name=dataset_name,
                                 transform=T.ToSparseTensor())
data = dataset[0]
data.adj_t = data.adj_t.to_symmetric()
device = 'cuda' if torch.cuda.is_available() else 'cpu'

print('Device: {}'.format(device))

data = data.to(device)
split_idx = dataset.get_idx_split()
train_idx = split_idx['train'].to(device)

# Construct the training dataloader for training data
# Sample 10 neighbors for each node in the first layer and 5 for the second layer
train_loader = NeighborSampler(data.adj_t, node_idx=train_idx,
                               sizes=[10, 5], batch_size=4096,
                               shuffle=True, num_workers=2)

# Specify size as -1 to include all neighbors
all_loader = NeighborSampler(data.adj_t, node_idx=None, sizes=[-1],
                                  batch_size=4096, shuffle=False,
                                  num_workers=2)
evaluator = Evaluator(name='ogbn-arxiv')
# Out:
# Downloading http://snap.stanford.edu/ogb/data/nodeproppred/arxiv.zip
# Downloaded 0.08 GB: 100%|██████████| 81/81 [00:01<00:00, 75.73it/s]
# Extracting dataset/arxiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████| 1/1 [00:00<00:00, 753.29it/s]
# Converting graphs into PyG objects...
# 100%|██████████| 1/1 [00:00<00:00, 314.11it/s]
# Saving...
# Done!
# Device: cuda
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:22: UserWarning: 'data.NeighborSampler' is deprecated, use 'loader.NeighborSampler' instead
#   warnings.warn(out)

# %% [markdown]
# ## GNN Model
#
# After creating the `NeighborSampler`, we also need to modify the model to let it support the mini-batch training.
#
# The `forward` function will take the node feature `x` and a list of three-element tuples `adjs`. Each element in `adjs` contains following elements:
# * `edge_index`: The edge index tensor between source and destination nodes, which forms a bipartite grpah.
# * `e_id`: The indices of the edges in the original graph.
# * `size`: The shape of the bipartite graph, in (*number of source nodes*, *number of destination nodes*) format.

# %%
class SAGE(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers,
                 dropout):
        super(SAGE, self).__init__()

        self.convs = torch.nn.ModuleList()
        self.bns = torch.nn.ModuleList()

        self.convs.append(SAGEConv(input_dim, hidden_dim))
        self.bns.append(torch.nn.BatchNorm1d(hidden_dim))

        for i in range(num_layers - 2):
            self.convs.append(
                SAGEConv(hidden_dim, hidden_dim))
            self.bns.append(torch.nn.BatchNorm1d(hidden_dim))
        self.convs.append(SAGEConv(hidden_dim, output_dim))

        self.softmax = torch.nn.LogSoftmax(dim=1)

        self.dropout = dropout

        self.num_layers = num_layers

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()
        for bn in self.bns:
            bn.reset_parameters()

    def forward(self, x, adjs, mode="batch"):
        if mode == "batch":
            for i, (edge_index, _, size) in enumerate(adjs):
                # Extract target node features
                x_target = x[:size[1]]

                # Update x for next layer reuse
                x = self.convs[i]((x, x_target), edge_index)
                if i != self.num_layers - 1:
                    x = self.bns[i](x)
                    x = F.relu(x)
                    x = F.dropout(x, p=self.dropout, training=self.training)
        else:
            for i, conv in enumerate(self.convs):
                x = conv(x, adjs)
                if i != self.num_layers - 1:
                    x = self.bns[i](x)
                    x = F.relu(x)
                    x = F.dropout(x, p=self.dropout, training=self.training)
        return self.softmax(x)

    def inference(self, x_all, all_loader):
        # This function will be called in test
        for i in range(self.num_layers):
            xs = []
            for batch_size, n_id, adj in all_loader:
                edge_index, _, size = adj.to(device)
                x = x_all[n_id].to(device)
                x_target = x[:size[1]]
                x = self.convs[i]((x, x_target), edge_index)
                if i != self.num_layers - 1:
                    x = self.bns[i](x)
                    x = F.relu(x)
                    x = F.dropout(x, p=self.dropout, training=self.training)

                # Append the node embeddings to xs
                xs.append(x.cpu())

            # Concat all embeddings into one tensor
            x_all = torch.cat(xs, dim=0)

        return x_all

# %% [markdown]
# ## Training and Testing
#
# Now lets implement the training and testing functions.
#
# In both training and testing, we need to sample batch from the dataloader.
#
# Each batch in the `NeighborSampler` dataloader holds three elements:
# * `batch_size`: The batch size specified in the dataloader.
# * `n_id`: All nodes (in index format) used in the adjacency matrices.
# * `adjs`: The three-element tuples.

# %%
def train(model, data, train_loader, train_idx, optimizer, loss_fn, mode="batch"):
    model.train()

    total_loss = 0
    if mode == "batch":
        for batch_size, n_id, adjs in train_loader:
            # Move all adj sparse tensors to GPU
            adjs = [adj.to(device) for adj in adjs]
            optimizer.zero_grad()

            # Index on the node features
            out = model(data.x[n_id], adjs)
            train_label = data.y[n_id[:batch_size]].squeeze(-1)
            loss = loss_fn(out, train_label)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
    else:
        optimizer.zero_grad()
        out = model(data.x, data.adj_t, mode=mode)[train_idx]
        train_label = data.y.squeeze(1)[train_idx]
        loss = loss_fn(out, train_label)
        loss.backward()
        optimizer.step()
        total_loss = loss.item()

    return total_loss

@torch.no_grad()
def test(model, data, all_loader, split_idx, evaluator, mode="batch"):
    model.eval()

    if mode == "batch":
        out = model.inference(data.x, all_loader)
    else:
        out = model(data.x, data.adj_t, mode="all")

    y_true = data.y.cpu()
    y_pred = out.argmax(dim=-1, keepdim=True)

    train_acc = evaluator.eval({
        'y_true': y_true[split_idx['train']],
        'y_pred': y_pred[split_idx['train']],
    })['acc']
    valid_acc = evaluator.eval({
        'y_true': y_true[split_idx['valid']],
        'y_pred': y_pred[split_idx['valid']],
    })['acc']
    test_acc = evaluator.eval({
        'y_true': y_true[split_idx['test']],
        'y_pred': y_pred[split_idx['test']],
    })['acc']

    return train_acc, valid_acc, test_acc

# %% [markdown]
# ## Mini-batch Training

# %%
args = {
    'device': device,
    'num_layers': 2,
    'hidden_dim': 128,
    'dropout': 0.5,
    'lr': 0.01,
    'epochs': 100,
}

batch_model = SAGE(data.num_features, args['hidden_dim'],
            dataset.num_classes, args['num_layers'],
            args['dropout']).to(device)
batch_model.reset_parameters()

optimizer = torch.optim.Adam(batch_model.parameters(), lr=args['lr'])
loss_fn = F.nll_loss

best_batch_model = None
best_valid_acc = 0

batch_results = []
losses , train_acc_list, valid_acc_list , test_acc_list = [],[],[],[]
for epoch in range(1, 1 + args["epochs"]):
    loss = train(batch_model, data, train_loader, train_idx, optimizer, loss_fn, mode="batch")
    result = test(batch_model, data, all_loader, split_idx, evaluator, mode="batch")
    batch_results.append(result)
    train_acc, valid_acc, test_acc = result
    losses.append(loss)
    train_acc_list.append(train_acc)
    valid_acc_list.append(valid_acc)
    test_acc_list.append(test_acc)
    if valid_acc > best_valid_acc:
        best_valid_acc = valid_acc
        best_batch_model = copy.deepcopy(batch_model)
    print(f'Epoch: {epoch:02d}, '
          f'Loss: {loss:.4f}, '
          f'Train: {100 * train_acc:.2f}%, '
          f'Valid: {100 * valid_acc:.2f}% '
          f'Test: {100 * test_acc:.2f}%')
best_result = test(best_batch_model, data, all_loader, split_idx, evaluator, mode="batch")
train_acc, valid_acc, test_acc = best_result
print(f'Best model: '
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * valid_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 40.0642, Train: 62.44%, Valid: 63.97% Test: 63.45%
# Epoch: 02, Loss: 28.5815, Train: 67.41%, Valid: 67.25% Test: 65.91%
# Epoch: 03, Loss: 26.6347, Train: 68.92%, Valid: 68.44% Test: 67.61%
# Epoch: 04, Loss: 25.7048, Train: 69.90%, Valid: 69.27% Test: 68.66%
# Epoch: 05, Loss: 25.0801, Train: 70.21%, Valid: 68.04% Test: 65.76%
# Epoch: 06, Loss: 24.6612, Train: 71.04%, Valid: 69.27% Test: 67.86%
# Epoch: 07, Loss: 24.2864, Train: 70.98%, Valid: 69.48% Test: 68.69%
# Epoch: 08, Loss: 24.0118, Train: 71.71%, Valid: 69.81% Test: 68.51%
# Epoch: 09, Loss: 23.7978, Train: 71.92%, Valid: 70.06% Test: 69.27%
# Epoch: 10, Loss: 23.4814, Train: 71.97%, Valid: 69.76% Test: 68.24%
# Epoch: 11, Loss: 23.4407, Train: 72.46%, Valid: 70.49% Test: 69.89%
# Epoch: 12, Loss: 23.1255, Train: 72.91%, Valid: 70.47% Test: 69.56%
# Epoch: 13, Loss: 23.0600, Train: 72.79%, Valid: 69.82% Test: 68.59%
# Epoch: 14, Loss: 22.9680, Train: 73.01%, Valid: 70.26% Test: 69.23%
# Epoch: 15, Loss: 22.8503, Train: 73.00%, Valid: 69.68% Test: 67.77%
# Epoch: 16, Loss: 22.6655, Train: 73.46%, Valid: 69.67% Test: 67.75%
# Epoch: 17, Loss: 22.5763, Train: 73.54%, Valid: 70.10% Test: 68.44%
# Epoch: 18, Loss: 22.5034, Train: 73.43%, Valid: 69.92% Test: 68.73%
# Epoch: 19, Loss: 22.4124, Train: 73.69%, Valid: 70.23% Test: 69.11%
# Epoch: 20, Loss: 22.3782, Train: 73.70%, Valid: 70.41% Test: 69.81%
# Epoch: 21, Loss: 22.1537, Train: 73.86%, Valid: 69.79% Test: 68.01%
# Epoch: 22, Loss: 22.1360, Train: 74.14%, Valid: 70.33% Test: 68.52%
# Epoch: 23, Loss: 22.1706, Train: 74.18%, Valid: 70.90% Test: 70.44%
# Epoch: 24, Loss: 21.9185, Train: 74.22%, Valid: 70.53% Test: 69.44%
# Epoch: 25, Loss: 21.9440, Train: 74.65%, Valid: 70.67% Test: 69.85%
# Epoch: 26, Loss: 21.8767, Train: 74.42%, Valid: 70.00% Test: 68.94%
# Epoch: 27, Loss: 21.8164, Train: 74.78%, Valid: 70.39% Test: 68.98%
# Epoch: 28, Loss: 21.8112, Train: 74.99%, Valid: 70.68% Test: 69.82%
# Epoch: 29, Loss: 21.8314, Train: 74.67%, Valid: 69.73% Test: 67.51%
# Epoch: 30, Loss: 21.6939, Train: 75.20%, Valid: 70.70% Test: 69.56%
# Epoch: 31, Loss: 21.5605, Train: 75.09%, Valid: 70.46% Test: 68.99%
# Epoch: 32, Loss: 21.6093, Train: 75.00%, Valid: 70.61% Test: 69.33%
# Epoch: 33, Loss: 21.5631, Train: 75.10%, Valid: 70.91% Test: 70.32%
# Epoch: 34, Loss: 21.5932, Train: 75.07%, Valid: 70.90% Test: 70.24%
# Epoch: 35, Loss: 21.4550, Train: 75.04%, Valid: 70.24% Test: 68.82%
# Epoch: 36, Loss: 21.4533, Train: 74.83%, Valid: 69.57% Test: 67.63%
# Epoch: 37, Loss: 21.3177, Train: 75.27%, Valid: 70.14% Test: 68.56%
# Epoch: 38, Loss: 21.3385, Train: 75.27%, Valid: 70.53% Test: 69.52%
# Epoch: 39, Loss: 21.3846, Train: 75.57%, Valid: 71.03% Test: 69.85%
# Epoch: 40, Loss: 21.3173, Train: 75.45%, Valid: 69.98% Test: 68.05%
# Epoch: 41, Loss: 21.2547, Train: 75.29%, Valid: 70.40% Test: 69.70%
# Epoch: 42, Loss: 21.2563, Train: 75.63%, Valid: 70.82% Test: 69.75%
# Epoch: 43, Loss: 21.1574, Train: 75.62%, Valid: 70.28% Test: 68.65%
# Epoch: 44, Loss: 21.1411, Train: 75.75%, Valid: 70.93% Test: 69.68%
# Epoch: 45, Loss: 21.1854, Train: 75.75%, Valid: 70.79% Test: 69.92%
# Epoch: 46, Loss: 21.0555, Train: 75.90%, Valid: 70.93% Test: 69.78%
# Epoch: 47, Loss: 21.1089, Train: 75.70%, Valid: 70.22% Test: 68.67%
# Epoch: 48, Loss: 20.9586, Train: 75.80%, Valid: 70.22% Test: 68.37%
# Epoch: 49, Loss: 21.0112, Train: 75.75%, Valid: 70.91% Test: 70.54%
# Epoch: 50, Loss: 21.0756, Train: 75.89%, Valid: 71.04% Test: 70.51%
# Epoch: 51, Loss: 20.9617, Train: 76.11%, Valid: 71.05% Test: 69.97%
# Epoch: 52, Loss: 20.9195, Train: 76.10%, Valid: 70.78% Test: 69.54%
# Epoch: 53, Loss: 20.8907, Train: 76.09%, Valid: 70.65% Test: 69.40%
# Epoch: 54, Loss: 20.8931, Train: 76.10%, Valid: 70.11% Test: 68.16%
# Epoch: 55, Loss: 20.9163, Train: 76.06%, Valid: 70.20% Test: 68.86%
# Epoch: 56, Loss: 20.8343, Train: 76.16%, Valid: 70.37% Test: 68.62%
# Epoch: 57, Loss: 20.8083, Train: 75.90%, Valid: 70.68% Test: 69.57%
# Epoch: 58, Loss: 20.8710, Train: 76.35%, Valid: 70.41% Test: 68.79%
# Epoch: 59, Loss: 20.7762, Train: 76.31%, Valid: 70.66% Test: 69.52%
# Epoch: 60, Loss: 20.7582, Train: 76.44%, Valid: 70.39% Test: 69.17%
# Epoch: 61, Loss: 20.7280, Train: 76.28%, Valid: 70.85% Test: 69.65%
# Epoch: 62, Loss: 20.7002, Train: 76.32%, Valid: 70.71% Test: 69.91%
# Epoch: 63, Loss: 20.6563, Train: 76.45%, Valid: 70.92% Test: 69.94%
# Epoch: 64, Loss: 20.8060, Train: 76.44%, Valid: 71.10% Test: 70.23%
# Epoch: 65, Loss: 20.6169, Train: 76.66%, Valid: 70.88% Test: 69.66%
# Epoch: 66, Loss: 20.6114, Train: 76.60%, Valid: 70.67% Test: 69.15%
# Epoch: 67, Loss: 20.6806, Train: 76.51%, Valid: 70.52% Test: 69.22%
# Epoch: 68, Loss: 20.7082, Train: 76.74%, Valid: 70.64% Test: 69.21%
# Epoch: 69, Loss: 20.5705, Train: 76.49%, Valid: 69.85% Test: 67.69%
# Epoch: 70, Loss: 20.5756, Train: 76.67%, Valid: 70.59% Test: 69.38%
# Epoch: 71, Loss: 20.6509, Train: 76.79%, Valid: 71.01% Test: 69.76%
# Epoch: 72, Loss: 20.5704, Train: 76.77%, Valid: 70.34% Test: 68.60%
# Epoch: 73, Loss: 20.5859, Train: 76.52%, Valid: 70.78% Test: 70.18%
# Epoch: 74, Loss: 20.4826, Train: 76.88%, Valid: 71.11% Test: 70.24%
# Epoch: 75, Loss: 20.3411, Train: 76.80%, Valid: 70.57% Test: 69.61%
# Epoch: 76, Loss: 20.6210, Train: 76.77%, Valid: 70.37% Test: 69.01%
# Epoch: 77, Loss: 20.5848, Train: 76.91%, Valid: 70.58% Test: 69.09%
# Epoch: 78, Loss: 20.3926, Train: 76.73%, Valid: 70.60% Test: 69.52%
# Epoch: 79, Loss: 20.4341, Train: 76.99%, Valid: 70.70% Test: 69.24%
# Epoch: 80, Loss: 20.4597, Train: 76.97%, Valid: 70.40% Test: 69.26%
# Epoch: 81, Loss: 20.4256, Train: 76.83%, Valid: 70.30% Test: 68.85%
# Epoch: 82, Loss: 20.4931, Train: 77.05%, Valid: 70.78% Test: 69.37%
# Epoch: 83, Loss: 20.4264, Train: 76.98%, Valid: 70.80% Test: 69.50%
# Epoch: 84, Loss: 20.4010, Train: 76.84%, Valid: 70.45% Test: 69.05%
# Epoch: 85, Loss: 20.3616, Train: 77.02%, Valid: 70.95% Test: 70.25%
# Epoch: 86, Loss: 20.4500, Train: 76.90%, Valid: 70.99% Test: 70.20%
# Epoch: 87, Loss: 20.3693, Train: 77.01%, Valid: 70.67% Test: 69.01%
# Epoch: 88, Loss: 20.3438, Train: 77.09%, Valid: 71.17% Test: 70.41%
# Epoch: 89, Loss: 20.3785, Train: 76.99%, Valid: 70.52% Test: 69.25%
# Epoch: 90, Loss: 20.3505, Train: 77.19%, Valid: 70.75% Test: 69.54%
# Epoch: 91, Loss: 20.2518, Train: 76.88%, Valid: 70.16% Test: 68.33%
# Epoch: 92, Loss: 20.3425, Train: 77.15%, Valid: 70.98% Test: 70.02%
# Epoch: 93, Loss: 20.2771, Train: 77.08%, Valid: 71.25% Test: 70.36%
# Epoch: 94, Loss: 20.2394, Train: 76.98%, Valid: 70.82% Test: 69.26%
# Epoch: 95, Loss: 20.3352, Train: 77.28%, Valid: 70.76% Test: 69.53%
# Epoch: 96, Loss: 20.3734, Train: 77.10%, Valid: 70.79% Test: 69.92%
# Epoch: 97, Loss: 20.3287, Train: 77.27%, Valid: 70.57% Test: 69.10%
# Epoch: 98, Loss: 20.3310, Train: 77.20%, Valid: 71.06% Test: 70.21%
# Epoch: 99, Loss: 20.2223, Train: 77.01%, Valid: 70.24% Test: 68.60%
# Epoch: 100, Loss: 20.1812, Train: 76.99%, Valid: 70.89% Test: 70.13%
# Best model: Train: 77.08%, Valid: 71.25% Test: 70.36%

# %%
import numpy as np
import matplotlib.pyplot as plt

epoch_list  = np.arange(len(losses))
plt.figure
plt.plot(epoch_list,losses)
plt.title("Losses")
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.show()

plt.figure()
plt.plot(epoch_list,train_acc_list , label = "Training")
plt.plot(epoch_list,valid_acc_list , label = "Validation")
plt.plot(epoch_list,test_acc_list , label = "Test")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Comparison")

plt.show()

# %% [markdown]
# ## Full-batch Training

# %%
# Use the same parameters for a full-batch training
args = {
    'device': device,
    'num_layers': 2,
    'hidden_dim': 128,
    'dropout': 0.5,
    'lr': 0.01,
    'epochs': 100,
}

all_model = SAGE(data.num_features, args['hidden_dim'],
            dataset.num_classes, args['num_layers'],
            args['dropout']).to(device)
all_model.reset_parameters()

optimizer = torch.optim.Adam(all_model.parameters(), lr=args['lr'])
loss_fn = F.nll_loss

best_all_model = None
best_valid_acc = 0

all_results = []
losses_all , train_acc_list_all, valid_acc_list_all , test_acc_list_all = [],[],[],[]

for epoch in range(1, 1 + args["epochs"]):
    loss = train(all_model, data, train_loader, train_idx, optimizer, loss_fn, mode="all")
    result = test(all_model, data, all_loader, split_idx, evaluator, mode="all")
    all_results.append(result)
    train_acc, valid_acc, test_acc = result
    losses_all.append(loss)
    train_acc_list_all.append(train_acc)
    valid_acc_list_all.append(valid_acc)
    test_acc_list_all.append(test_acc)
    if valid_acc > best_valid_acc:
        best_valid_acc = valid_acc
        best_all_model = copy.deepcopy(all_model)
    print(f'Epoch: {epoch:02d}, '
          f'Loss: {loss:.4f}, '
          f'Train: {100 * train_acc:.2f}%, '
          f'Valid: {100 * valid_acc:.2f}% '
          f'Test: {100 * test_acc:.2f}%')

best_result = test(best_all_model, data, all_loader, split_idx, evaluator, mode="all")
train_acc, valid_acc, test_acc = best_result
print(f'Best model: '
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * valid_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 3.9569, Train: 35.92%, Valid: 41.58% Test: 40.15%
# Epoch: 02, Loss: 2.5774, Train: 34.31%, Valid: 39.87% Test: 40.75%
# Epoch: 03, Loss: 2.2059, Train: 34.31%, Valid: 41.74% Test: 44.73%
# Epoch: 04, Loss: 2.0452, Train: 36.40%, Valid: 43.49% Test: 46.93%
# Epoch: 05, Loss: 1.9113, Train: 41.38%, Valid: 47.90% Test: 50.94%
# Epoch: 06, Loss: 1.7996, Train: 46.28%, Valid: 51.95% Test: 54.21%
# Epoch: 07, Loss: 1.7095, Train: 48.94%, Valid: 54.21% Test: 55.23%
# Epoch: 08, Loss: 1.6399, Train: 50.69%, Valid: 55.32% Test: 55.53%
# Epoch: 09, Loss: 1.5943, Train: 52.40%, Valid: 56.65% Test: 56.84%
# Epoch: 10, Loss: 1.5471, Train: 54.16%, Valid: 58.24% Test: 58.77%
# Epoch: 11, Loss: 1.5010, Train: 55.53%, Valid: 59.31% Test: 60.22%
# Epoch: 12, Loss: 1.4645, Train: 56.55%, Valid: 60.04% Test: 61.11%
# Epoch: 13, Loss: 1.4321, Train: 57.62%, Valid: 60.92% Test: 61.72%
# Epoch: 14, Loss: 1.4019, Train: 58.59%, Valid: 61.49% Test: 62.08%
# Epoch: 15, Loss: 1.3763, Train: 59.52%, Valid: 62.10% Test: 62.33%
# Epoch: 16, Loss: 1.3561, Train: 60.22%, Valid: 62.63% Test: 62.58%
# Epoch: 17, Loss: 1.3419, Train: 61.00%, Valid: 63.20% Test: 62.92%
# Epoch: 18, Loss: 1.3255, Train: 61.67%, Valid: 63.67% Test: 63.37%
# Epoch: 19, Loss: 1.3085, Train: 62.29%, Valid: 64.31% Test: 63.97%
# Epoch: 20, Loss: 1.2989, Train: 62.94%, Valid: 64.80% Test: 64.44%
# Epoch: 21, Loss: 1.2848, Train: 63.52%, Valid: 65.08% Test: 64.73%
# Epoch: 22, Loss: 1.2772, Train: 64.05%, Valid: 65.22% Test: 64.96%
# Epoch: 23, Loss: 1.2646, Train: 64.42%, Valid: 65.37% Test: 65.02%
# Epoch: 24, Loss: 1.2557, Train: 64.77%, Valid: 65.44% Test: 64.94%
# Epoch: 25, Loss: 1.2412, Train: 64.99%, Valid: 65.49% Test: 64.87%
# Epoch: 26, Loss: 1.2321, Train: 65.21%, Valid: 65.58% Test: 64.77%
# Epoch: 27, Loss: 1.2225, Train: 65.41%, Valid: 65.73% Test: 64.83%
# Epoch: 28, Loss: 1.2140, Train: 65.65%, Valid: 65.91% Test: 64.90%
# Epoch: 29, Loss: 1.2093, Train: 65.93%, Valid: 66.07% Test: 65.10%
# Epoch: 30, Loss: 1.2004, Train: 66.22%, Valid: 66.34% Test: 65.33%
# Epoch: 31, Loss: 1.1898, Train: 66.47%, Valid: 66.54% Test: 65.57%
# Epoch: 32, Loss: 1.1846, Train: 66.69%, Valid: 66.75% Test: 65.76%
# Epoch: 33, Loss: 1.1747, Train: 66.90%, Valid: 66.90% Test: 65.93%
# Epoch: 34, Loss: 1.1706, Train: 67.09%, Valid: 67.03% Test: 66.12%
# Epoch: 35, Loss: 1.1667, Train: 67.27%, Valid: 67.25% Test: 66.32%
# Epoch: 36, Loss: 1.1563, Train: 67.40%, Valid: 67.46% Test: 66.46%
# Epoch: 37, Loss: 1.1533, Train: 67.62%, Valid: 67.57% Test: 66.65%
# Epoch: 38, Loss: 1.1472, Train: 67.76%, Valid: 67.60% Test: 66.82%
# Epoch: 39, Loss: 1.1411, Train: 67.92%, Valid: 67.71% Test: 66.94%
# Epoch: 40, Loss: 1.1403, Train: 67.97%, Valid: 67.80% Test: 67.07%
# Epoch: 41, Loss: 1.1364, Train: 68.09%, Valid: 67.91% Test: 67.22%
# Epoch: 42, Loss: 1.1295, Train: 68.24%, Valid: 68.12% Test: 67.36%
# Epoch: 43, Loss: 1.1248, Train: 68.42%, Valid: 68.18% Test: 67.47%
# Epoch: 44, Loss: 1.1219, Train: 68.56%, Valid: 68.30% Test: 67.60%
# Epoch: 45, Loss: 1.1155, Train: 68.71%, Valid: 68.45% Test: 67.62%
# Epoch: 46, Loss: 1.1122, Train: 68.82%, Valid: 68.46% Test: 67.64%
# Epoch: 47, Loss: 1.1074, Train: 68.95%, Valid: 68.47% Test: 67.62%
# Epoch: 48, Loss: 1.1064, Train: 69.04%, Valid: 68.48% Test: 67.54%
# Epoch: 49, Loss: 1.1029, Train: 69.07%, Valid: 68.43% Test: 67.39%
# Epoch: 50, Loss: 1.0988, Train: 69.13%, Valid: 68.39% Test: 67.28%
# Epoch: 51, Loss: 1.0934, Train: 69.18%, Valid: 68.40% Test: 67.26%
# Epoch: 52, Loss: 1.0922, Train: 69.30%, Valid: 68.47% Test: 67.23%
# Epoch: 53, Loss: 1.0875, Train: 69.38%, Valid: 68.44% Test: 67.18%
# Epoch: 54, Loss: 1.0823, Train: 69.44%, Valid: 68.47% Test: 67.16%
# Epoch: 55, Loss: 1.0818, Train: 69.56%, Valid: 68.52% Test: 67.15%
# Epoch: 56, Loss: 1.0804, Train: 69.66%, Valid: 68.59% Test: 67.22%
# Epoch: 57, Loss: 1.0729, Train: 69.77%, Valid: 68.71% Test: 67.26%
# Epoch: 58, Loss: 1.0724, Train: 69.86%, Valid: 68.77% Test: 67.42%
# Epoch: 59, Loss: 1.0695, Train: 69.96%, Valid: 68.82% Test: 67.47%
# Epoch: 60, Loss: 1.0696, Train: 70.11%, Valid: 68.91% Test: 67.51%
# Epoch: 61, Loss: 1.0662, Train: 70.20%, Valid: 68.83% Test: 67.41%
# Epoch: 62, Loss: 1.0625, Train: 70.27%, Valid: 68.80% Test: 67.34%
# Epoch: 63, Loss: 1.0557, Train: 70.32%, Valid: 68.77% Test: 67.28%
# Epoch: 64, Loss: 1.0571, Train: 70.39%, Valid: 68.78% Test: 67.35%
# Epoch: 65, Loss: 1.0542, Train: 70.45%, Valid: 68.87% Test: 67.49%
# Epoch: 66, Loss: 1.0521, Train: 70.54%, Valid: 69.01% Test: 67.59%
# Epoch: 67, Loss: 1.0505, Train: 70.58%, Valid: 69.04% Test: 67.60%
# Epoch: 68, Loss: 1.0461, Train: 70.60%, Valid: 69.03% Test: 67.59%
# Epoch: 69, Loss: 1.0452, Train: 70.70%, Valid: 69.02% Test: 67.57%
# Epoch: 70, Loss: 1.0408, Train: 70.72%, Valid: 68.92% Test: 67.38%
# Epoch: 71, Loss: 1.0401, Train: 70.77%, Valid: 68.91% Test: 67.28%
# Epoch: 72, Loss: 1.0370, Train: 70.89%, Valid: 68.98% Test: 67.38%
# Epoch: 73, Loss: 1.0378, Train: 70.97%, Valid: 69.09% Test: 67.56%
# Epoch: 74, Loss: 1.0318, Train: 71.05%, Valid: 69.20% Test: 67.66%
# Epoch: 75, Loss: 1.0315, Train: 71.11%, Valid: 69.25% Test: 67.64%
# Epoch: 76, Loss: 1.0302, Train: 71.13%, Valid: 69.13% Test: 67.50%
# Epoch: 77, Loss: 1.0282, Train: 71.16%, Valid: 69.06% Test: 67.35%
# Epoch: 78, Loss: 1.0292, Train: 71.24%, Valid: 69.13% Test: 67.40%
# Epoch: 79, Loss: 1.0231, Train: 71.31%, Valid: 69.19% Test: 67.58%
# Epoch: 80, Loss: 1.0217, Train: 71.41%, Valid: 69.39% Test: 67.98%
# Epoch: 81, Loss: 1.0207, Train: 71.51%, Valid: 69.47% Test: 68.24%
# Epoch: 82, Loss: 1.0188, Train: 71.52%, Valid: 69.57% Test: 68.30%
# Epoch: 83, Loss: 1.0154, Train: 71.56%, Valid: 69.56% Test: 68.11%
# Epoch: 84, Loss: 1.0153, Train: 71.58%, Valid: 69.47% Test: 67.81%
# Epoch: 85, Loss: 1.0135, Train: 71.58%, Valid: 69.41% Test: 67.70%
# Epoch: 86, Loss: 1.0104, Train: 71.62%, Valid: 69.51% Test: 67.91%
# Epoch: 87, Loss: 1.0097, Train: 71.71%, Valid: 69.75% Test: 68.34%
# Epoch: 88, Loss: 1.0074, Train: 71.75%, Valid: 69.85% Test: 68.61%
# Epoch: 89, Loss: 1.0066, Train: 71.82%, Valid: 69.86% Test: 68.70%
# Epoch: 90, Loss: 1.0026, Train: 71.84%, Valid: 69.86% Test: 68.59%
# Epoch: 91, Loss: 1.0054, Train: 71.84%, Valid: 69.86% Test: 68.56%
# Epoch: 92, Loss: 0.9993, Train: 71.89%, Valid: 69.87% Test: 68.58%
# Epoch: 93, Loss: 1.0009, Train: 71.91%, Valid: 69.90% Test: 68.57%
# Epoch: 94, Loss: 0.9963, Train: 71.92%, Valid: 69.84% Test: 68.51%
# Epoch: 95, Loss: 0.9958, Train: 71.93%, Valid: 69.79% Test: 68.49%
# Epoch: 96, Loss: 0.9973, Train: 71.94%, Valid: 69.87% Test: 68.55%
# Epoch: 97, Loss: 0.9934, Train: 71.99%, Valid: 69.92% Test: 68.66%
# Epoch: 98, Loss: 0.9926, Train: 72.06%, Valid: 69.89% Test: 68.66%
# Epoch: 99, Loss: 0.9882, Train: 72.06%, Valid: 69.96% Test: 68.64%
# Epoch: 100, Loss: 0.9851, Train: 72.07%, Valid: 69.98% Test: 68.61%
# Best model: Train: 72.07%, Valid: 69.98% Test: 68.61%

# %%
import numpy as np
import matplotlib.pyplot as plt

epoch_list  = np.arange(len(losses_all))
plt.figure
plt.plot(epoch_list,losses_all)
plt.title("Losses")
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.show()

plt.figure()
plt.plot(epoch_list,train_acc_list_all , label = "Training")
plt.plot(epoch_list,valid_acc_list_all , label = "Validation")
plt.plot(epoch_list,test_acc_list_all , label = "Test")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Comparison")

plt.show()

# %% [markdown]
# ## Visualization

# %%
import numpy as np
from matplotlib import pyplot as plt

batch_results = np.array(batch_results)
all_results = np.array(all_results)

x = np.arange(1, 101)

plt.figure(figsize=(9, 7))

plt.plot(x, batch_results[:, 1], label="Batch Validation")
plt.plot(x, batch_results[:, 2], label="Batch Test")
plt.plot(x, all_results[:, 1], label="All Validation")
plt.plot(x, all_results[:, 2], label="All Test")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# # 2 Neighbor Sampling with Different Ratios
#
# Now we will implement a simplified version of Neighbor Sampling by using DeepSNAP and NetworkX, and train models with different neighborhood sampling ratios.
#
# To make the experiments faster, we will use the Cora graph here.

# %% [markdown]
# ## Setup

# %%
import copy
import torch
import random
import numpy as np
import networkx as nx
import torch.nn as nn
import torch.nn.functional as F

from torch_geometric.nn import SAGEConv
from torch.utils.data import DataLoader
from torch_geometric.datasets import Planetoid
from torch.nn import Sequential, Linear, ReLU
from deepsnap.dataset import GraphDataset
from deepsnap.graph import Graph

pyg_dataset = Planetoid('./tmp', "Cora")
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %% [markdown]
# ## GNN Model

# %%
class GNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, args):
        super(GNN, self).__init__()
        self.dropout = args['dropout']
        self.num_layers = args['num_layers']

        self.convs = nn.ModuleList()
        self.bns = nn.ModuleList()

        self.convs.append(SAGEConv(input_dim, hidden_dim))
        self.bns.append(nn.BatchNorm1d(hidden_dim))

        for l in range(self.num_layers - 2):
            self.convs.append(SAGEConv(hidden_dim, hidden_dim))
            self.bns.append(nn.BatchNorm1d(hidden_dim))
        self.convs.append(SAGEConv(hidden_dim, hidden_dim))

        self.post_mp = nn.Linear(hidden_dim, output_dim)

    def forward(self, data, mode="batch"):
        if mode == "batch":
            edge_indices, x = data
            for i in range(len(self.convs) - 1):
                edge_index = edge_indices[i]
                x = self.convs[i](x, edge_index)
                x = self.bns[i](x)
                x = F.relu(x)
                x = F.dropout(x, p=self.dropout, training=self.training)
            x = self.convs[-1](x, edge_indices[len(self.convs) - 1])
        else:
            x, edge_index = data.node_feature, data.edge_index
            for i in range(len(self.convs) - 1):
                x = self.convs[i](x, edge_index)
                x = self.bns[i](x)
                x = F.relu(x)
                x = F.dropout(x, p=self.dropout, training=self.training)
            x = self.convs[-1](x, edge_index)
        x = self.post_mp(x)
        x = F.log_softmax(x, dim=1)
        return x

# %% [markdown]
# ## Neighbor Sampling
#
# Here we implement functions that will sample neighbors by using DeepSNAP and NetworkX.
#
# Notice that node classification task on Cora is a semi-supervised classification task, here we keep all the labeled training nodes (140 nodes) by setting the last ratio to 1.

# %%
def sample_neighbors(nodes, G, ratio, all_nodes):
    # This fuction takes a set of nodes, a NetworkX graph G and neighbor sampling ratio.
    # It will return sampled neighbors (unioned with input nodes) and edges between
    neighbors = set()
    edges = []
    for node in nodes:
        neighbors_list = list(nx.neighbors(G, node))

        # We only sample the (ratio * number of neighbors) neighbors
        num = int(len(neighbors_list) * ratio)
        if num > 0:
            # Random shuffle the neighbors
            random.shuffle(neighbors_list)
            neighbors_list = neighbors_list[:num]
            for neighbor in neighbors_list:
                # Add neighbors
                neighbors.add(neighbor)
                edges.append((neighbor, node))
    return neighbors, neighbors.union(all_nodes), edges

def nodes_to_tensor(nodes):
    # This function transform a set of nodes to node index tensor
    node_label_index = torch.tensor(list(nodes), dtype=torch.long)
    return node_label_index

def edges_to_tensor(edges):
    # This function transform a set of edges to edge index tensor
    edge_index = torch.tensor(list(edges), dtype=torch.long)
    edge_index = torch.cat([edge_index, torch.flip(edge_index, [1])], dim=0)
    edge_index = edge_index.permute(1, 0)
    return edge_index

def relable(nodes, labeled_nodes, edges_list):
    # Relable the nodes, labeled_nodes and edges_list
    relabled_edges_list = []
    sorted_nodes = sorted(nodes)
    node_mapping = {node : i for i, node in enumerate(sorted_nodes)}
    for orig_edges in edges_list:
        relabeled_edges = []
        for edge in orig_edges:
            relabeled_edges.append((node_mapping[edge[0]], node_mapping[edge[1]]))
        relabled_edges_list.append(relabeled_edges)
    relabeled_labeled_nodes = [node_mapping[node] for node in labeled_nodes]
    relabeled_nodes = [node_mapping[node] for node in nodes]
    return relabled_edges_list, relabeled_nodes, relabeled_labeled_nodes

def neighbor_sampling(graph, K=2, ratios=(0.1, 0.1, 0.1)):
    # This function takes a DeepSNAP graph, K the number of GNN layers, and neighbor
    # sampling ratios for each layer. This function returns relabeled node feature,
    # edge indices and node_label_index

    assert K + 1 == len(ratios)

    labeled_nodes = graph.node_label_index.tolist()
    random.shuffle(labeled_nodes)
    num = int(len(labeled_nodes) * ratios[-1])
    if num > 0:
        labeled_nodes = labeled_nodes[:num]
    nodes_list = [set(labeled_nodes)]
    edges_list = []
    all_nodes = labeled_nodes
    for k in range(K):
        # Get nodes and edges from the previous layer
        nodes, all_nodes, edges = \
            sample_neighbors(nodes_list[-1], graph.G, ratios[len(ratios) - k - 2], all_nodes)
        nodes_list.append(nodes)
        edges_list.append(edges)

    # Reverse the lists
    nodes_list.reverse()
    edges_list.reverse()

    relabled_edges_list, relabeled_all_nodes, relabeled_labeled_nodes = \
        relable(all_nodes, labeled_nodes, edges_list)

    node_index = nodes_to_tensor(relabeled_all_nodes)
    # All node features that will be used
    node_feature = graph.node_feature[node_index]
    edge_indices = [edges_to_tensor(edges) for edges in relabled_edges_list]
    node_label_index = nodes_to_tensor(relabeled_labeled_nodes)
    log = "Sampled {} nodes, {} edges, {} labeled nodes"
    print(log.format(node_feature.shape[0], edge_indices[0].shape[1] // 2, node_label_index.shape[0]))
    return node_feature, edge_indices, node_label_index

# %% [markdown]
# ## Training and Testing

# %%
def train(train_graphs, val_graphs, args, model, optimizer, mode="batch"):
    best_val = 0
    best_model = None
    accs = []
    graph_train = train_graphs[0]
    graph_train.to(args['device'])
    for epoch in range(1, 1 + args['epochs']):
        model.train()
        optimizer.zero_grad()
        if mode == "batch":
            node_feature, edge_indices, node_label_index = neighbor_sampling(graph_train, args['num_layers'], args['ratios'])
            node_feature = node_feature.to(args['device'])
            node_label_index = node_label_index.to(args['device'])
            for i in range(len(edge_indices)):
                edge_indices[i] = edge_indices[i].to(args['device'])
            pred = model([edge_indices, node_feature])
            pred = pred[node_label_index]
            label = graph_train.node_label[node_label_index]
        elif mode == "community":
            graph = random.choice(train_graphs)
            graph = graph.to(args['device'])
            pred = model(graph, mode="all")
            pred = pred[graph.node_label_index]
            label = graph.node_label[graph.node_label_index]
        else:
            pred = model(graph_train, mode="all")
            label = graph_train.node_label
            pred = pred[graph_train.node_label_index]
        loss = F.nll_loss(pred, label)
        loss.backward()
        optimizer.step()

        train_acc, val_acc, test_acc = test(val_graphs, model)
        accs.append((train_acc, val_acc, test_acc))
        if val_acc > best_val:
            best_val = val_acc
            best_model = copy.deepcopy(model)
        print(f'Epoch: {epoch:02d}, '
              f'Loss: {loss:.4f}, '
              f'Train: {100 * train_acc:.2f}%, '
              f'Valid: {100 * val_acc:.2f}% '
              f'Test: {100 * test_acc:.2f}%')
    return best_model, accs

def test(graphs, model):
    model.eval()
    accs = []
    for graph in graphs:
        graph = graph.to(args['device'])
        pred = model(graph, mode="all")
        label = graph.node_label
        pred = pred[graph.node_label_index].max(1)[1]
        acc = pred.eq(label).sum().item()
        acc /= len(label)
        accs.append(acc)
    return accs

# %%
args = {
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'dropout': 0.5,
    'num_layers': 2,
    'hidden_size': 64,
    'lr': 0.005,
    'epochs': 50,
    'ratios': (0.8, 0.8, 1),
}

# %% [markdown]
# ## Full-Batch Training

# %%
graphs_train, graphs_val, graphs_test = \
    GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

graph_train = graphs_train[0]
graph_val = graphs_val[0]
graph_test = graphs_test[0]

model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
graphs = [graph_train, graph_val, graph_test]
all_best_model, all_accs = train(graphs, graphs, args, model, optimizer, mode="all")
train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], all_best_model)
print('Best model:',
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * val_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Index fields: val_mask ignored.
# Index fields: test_mask ignored.
# Index fields: train_mask ignored.
# Epoch: 01, Loss: 2.0179, Train: 25.00%, Valid: 9.60% Test: 11.40%
# Epoch: 02, Loss: 1.1945, Train: 80.00%, Valid: 22.80% Test: 26.40%
# Epoch: 03, Loss: 0.6367, Train: 95.71%, Valid: 46.40% Test: 48.60%
# Epoch: 04, Loss: 0.3621, Train: 97.86%, Valid: 58.60% Test: 59.90%
# Epoch: 05, Loss: 0.1522, Train: 99.29%, Valid: 63.00% Test: 66.40%
# Epoch: 06, Loss: 0.0946, Train: 100.00%, Valid: 67.60% Test: 68.80%
# Epoch: 07, Loss: 0.0500, Train: 100.00%, Valid: 69.20% Test: 70.10%
# Epoch: 08, Loss: 0.0248, Train: 100.00%, Valid: 70.80% Test: 71.30%
# Epoch: 09, Loss: 0.0189, Train: 100.00%, Valid: 72.00% Test: 73.30%
# Epoch: 10, Loss: 0.0114, Train: 100.00%, Valid: 73.60% Test: 74.50%
# Epoch: 11, Loss: 0.0064, Train: 100.00%, Valid: 74.20% Test: 75.10%
# Epoch: 12, Loss: 0.0074, Train: 100.00%, Valid: 75.40% Test: 75.30%
# Epoch: 13, Loss: 0.0227, Train: 100.00%, Valid: 75.20% Test: 75.30%
# Epoch: 14, Loss: 0.0020, Train: 100.00%, Valid: 75.00% Test: 76.00%
# Epoch: 15, Loss: 0.0036, Train: 100.00%, Valid: 75.40% Test: 76.10%
# Epoch: 16, Loss: 0.0013, Train: 100.00%, Valid: 74.80% Test: 75.90%
# Epoch: 17, Loss: 0.0004, Train: 100.00%, Valid: 74.60% Test: 75.40%
# Epoch: 18, Loss: 0.0010, Train: 100.00%, Valid: 75.00% Test: 76.00%
# Epoch: 19, Loss: 0.0003, Train: 100.00%, Valid: 75.40% Test: 76.00%
# Epoch: 20, Loss: 0.0002, Train: 100.00%, Valid: 75.00% Test: 75.70%
# Epoch: 21, Loss: 0.0004, Train: 100.00%, Valid: 74.60% Test: 75.90%
# Epoch: 22, Loss: 0.0002, Train: 100.00%, Valid: 74.20% Test: 75.80%
# Epoch: 23, Loss: 0.0002, Train: 100.00%, Valid: 74.40% Test: 75.70%
# Epoch: 24, Loss: 0.0007, Train: 100.00%, Valid: 74.40% Test: 75.70%
# Epoch: 25, Loss: 0.0001, Train: 100.00%, Valid: 74.40% Test: 75.70%
# Epoch: 26, Loss: 0.0004, Train: 100.00%, Valid: 74.40% Test: 76.00%
# Epoch: 27, Loss: 0.0020, Train: 100.00%, Valid: 74.20% Test: 76.00%
# Epoch: 28, Loss: 0.0007, Train: 100.00%, Valid: 74.20% Test: 76.00%
# Epoch: 29, Loss: 0.0003, Train: 100.00%, Valid: 74.40% Test: 75.90%
# Epoch: 30, Loss: 0.0078, Train: 100.00%, Valid: 74.20% Test: 75.70%
# Epoch: 31, Loss: 0.0012, Train: 100.00%, Valid: 73.80% Test: 75.70%
# Epoch: 32, Loss: 0.0000, Train: 100.00%, Valid: 73.80% Test: 75.70%
# Epoch: 33, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.70%
# Epoch: 34, Loss: 0.0006, Train: 100.00%, Valid: 73.40% Test: 75.80%
# Epoch: 35, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.50%
# Epoch: 36, Loss: 0.0106, Train: 100.00%, Valid: 73.60% Test: 75.40%
# Epoch: 37, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.30%
# Epoch: 38, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 75.50%
# Epoch: 39, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.40%
# Epoch: 40, Loss: 0.0003, Train: 100.00%, Valid: 73.20% Test: 75.50%
# Epoch: 41, Loss: 0.0004, Train: 100.00%, Valid: 73.20% Test: 75.50%
# Epoch: 42, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 75.50%
# Epoch: 43, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 75.60%
# Epoch: 44, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 75.60%
# Epoch: 45, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 75.50%
# Epoch: 46, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 75.40%
# Epoch: 47, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 75.50%
# Epoch: 48, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 75.60%
# Epoch: 49, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 75.60%
# Epoch: 50, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 75.30%
# Best model: Train: 100.00%, Valid: 75.40% Test: 75.30%

# %% [markdown]
# ## Sampling with Ratios 0.8

# %%
args['ratios'] = (0.8, 0.8, 1)

graphs_train, graphs_val, graphs_test = \
    GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

graph_train = graphs_train[0]
graph_val = graphs_val[0]
graph_test = graphs_test[0]

model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
graphs = [graph_train, graph_val, graph_test]
batch_best_model, batch_accs = train(graphs, graphs, args, model, optimizer)
train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], batch_best_model)
print('Best model:',
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * val_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Index fields: val_mask ignored.
# Index fields: test_mask ignored.
# Index fields: train_mask ignored.
# Sampled 1292 nodes, 2012 edges, 140 labeled nodes
# Epoch: 01, Loss: 2.0621, Train: 22.86%, Valid: 15.80% Test: 14.60%
# Sampled 1344 nodes, 2012 edges, 140 labeled nodes
# Epoch: 02, Loss: 1.6902, Train: 42.14%, Valid: 16.80% Test: 18.10%
# Sampled 1339 nodes, 2039 edges, 140 labeled nodes
# Epoch: 03, Loss: 1.3845, Train: 63.57%, Valid: 21.40% Test: 24.30%
# Sampled 1361 nodes, 2055 edges, 140 labeled nodes
# Epoch: 04, Loss: 1.1892, Train: 78.57%, Valid: 25.60% Test: 27.70%
# Sampled 1339 nodes, 2016 edges, 140 labeled nodes
# Epoch: 05, Loss: 0.9061, Train: 85.00%, Valid: 29.00% Test: 31.30%
# Sampled 1297 nodes, 1933 edges, 140 labeled nodes
# Epoch: 06, Loss: 0.7352, Train: 90.00%, Valid: 32.60% Test: 35.40%
# Sampled 1328 nodes, 2012 edges, 140 labeled nodes
# Epoch: 07, Loss: 0.5094, Train: 93.57%, Valid: 35.80% Test: 38.50%
# Sampled 1353 nodes, 2005 edges, 140 labeled nodes
# Epoch: 08, Loss: 0.3959, Train: 95.00%, Valid: 40.00% Test: 42.80%
# Sampled 1291 nodes, 1913 edges, 140 labeled nodes
# Epoch: 09, Loss: 0.3408, Train: 96.43%, Valid: 44.40% Test: 46.60%
# Sampled 1361 nodes, 2047 edges, 140 labeled nodes
# Epoch: 10, Loss: 0.2031, Train: 97.86%, Valid: 46.80% Test: 48.90%
# Sampled 1303 nodes, 1952 edges, 140 labeled nodes
# Epoch: 11, Loss: 0.1805, Train: 98.57%, Valid: 49.60% Test: 50.40%
# Sampled 1311 nodes, 2000 edges, 140 labeled nodes
# Epoch: 12, Loss: 0.1273, Train: 99.29%, Valid: 51.20% Test: 51.80%
# Sampled 1354 nodes, 2019 edges, 140 labeled nodes
# Epoch: 13, Loss: 0.1165, Train: 99.29%, Valid: 52.20% Test: 52.50%
# Sampled 1346 nodes, 2028 edges, 140 labeled nodes
# Epoch: 14, Loss: 0.0980, Train: 100.00%, Valid: 53.00% Test: 53.60%
# Sampled 1312 nodes, 1982 edges, 140 labeled nodes
# Epoch: 15, Loss: 0.0801, Train: 100.00%, Valid: 53.00% Test: 54.60%
# Sampled 1330 nodes, 1991 edges, 140 labeled nodes
# Epoch: 16, Loss: 0.0518, Train: 100.00%, Valid: 53.40% Test: 54.80%
# Sampled 1294 nodes, 1905 edges, 140 labeled nodes
# Epoch: 17, Loss: 0.0287, Train: 100.00%, Valid: 53.80% Test: 55.20%
# Sampled 1332 nodes, 2028 edges, 140 labeled nodes
# Epoch: 18, Loss: 0.0446, Train: 100.00%, Valid: 53.00% Test: 55.50%
# Sampled 1281 nodes, 1934 edges, 140 labeled nodes
# Epoch: 19, Loss: 0.1076, Train: 100.00%, Valid: 53.00% Test: 56.00%
# Sampled 1347 nodes, 2006 edges, 140 labeled nodes
# Epoch: 20, Loss: 0.0345, Train: 100.00%, Valid: 52.80% Test: 56.00%
# Sampled 1349 nodes, 2035 edges, 140 labeled nodes
# Epoch: 21, Loss: 0.0136, Train: 100.00%, Valid: 52.80% Test: 56.30%
# Sampled 1291 nodes, 1975 edges, 140 labeled nodes
# Epoch: 22, Loss: 0.0653, Train: 100.00%, Valid: 52.20% Test: 56.10%
# Sampled 1313 nodes, 2011 edges, 140 labeled nodes
# Epoch: 23, Loss: 0.0217, Train: 100.00%, Valid: 52.40% Test: 56.80%
# Sampled 1322 nodes, 2019 edges, 140 labeled nodes
# Epoch: 24, Loss: 0.0139, Train: 100.00%, Valid: 52.00% Test: 56.90%
# Sampled 1336 nodes, 1958 edges, 140 labeled nodes
# Epoch: 25, Loss: 0.0188, Train: 100.00%, Valid: 52.20% Test: 56.30%
# Sampled 1305 nodes, 1956 edges, 140 labeled nodes
# Epoch: 26, Loss: 0.0122, Train: 100.00%, Valid: 53.00% Test: 55.40%
# Sampled 1330 nodes, 1983 edges, 140 labeled nodes
# Epoch: 27, Loss: 0.0164, Train: 100.00%, Valid: 52.60% Test: 55.40%
# Sampled 1352 nodes, 2048 edges, 140 labeled nodes
# Epoch: 28, Loss: 0.0100, Train: 100.00%, Valid: 52.60% Test: 55.10%
# Sampled 1245 nodes, 1888 edges, 140 labeled nodes
# Epoch: 29, Loss: 0.0062, Train: 100.00%, Valid: 52.00% Test: 54.50%
# Sampled 1293 nodes, 1968 edges, 140 labeled nodes
# Epoch: 30, Loss: 0.0148, Train: 100.00%, Valid: 51.80% Test: 54.40%
# Sampled 1326 nodes, 1979 edges, 140 labeled nodes
# Epoch: 31, Loss: 0.0177, Train: 100.00%, Valid: 52.00% Test: 53.90%
# Sampled 1315 nodes, 2029 edges, 140 labeled nodes
# Epoch: 32, Loss: 0.0164, Train: 100.00%, Valid: 52.00% Test: 53.60%
# Sampled 1253 nodes, 1923 edges, 140 labeled nodes
# Epoch: 33, Loss: 0.0117, Train: 100.00%, Valid: 51.60% Test: 53.40%
# Sampled 1331 nodes, 2004 edges, 140 labeled nodes
# Epoch: 34, Loss: 0.0096, Train: 100.00%, Valid: 51.20% Test: 53.70%
# Sampled 1305 nodes, 2006 edges, 140 labeled nodes
# Epoch: 35, Loss: 0.0521, Train: 100.00%, Valid: 50.80% Test: 53.50%
# Sampled 1308 nodes, 1960 edges, 140 labeled nodes
# Epoch: 36, Loss: 0.0186, Train: 100.00%, Valid: 50.20% Test: 53.00%
# Sampled 1357 nodes, 2071 edges, 140 labeled nodes
# Epoch: 37, Loss: 0.0188, Train: 100.00%, Valid: 50.00% Test: 53.20%
# Sampled 1353 nodes, 2015 edges, 140 labeled nodes
# Epoch: 38, Loss: 0.0197, Train: 100.00%, Valid: 50.20% Test: 53.40%
# Sampled 1328 nodes, 2027 edges, 140 labeled nodes
# Epoch: 39, Loss: 0.0015, Train: 100.00%, Valid: 51.00% Test: 53.40%
# Sampled 1320 nodes, 1994 edges, 140 labeled nodes
# Epoch: 40, Loss: 0.0217, Train: 100.00%, Valid: 51.00% Test: 53.40%
# Sampled 1307 nodes, 1989 edges, 140 labeled nodes
# Epoch: 41, Loss: 0.0069, Train: 100.00%, Valid: 50.80% Test: 53.30%
# Sampled 1300 nodes, 1975 edges, 140 labeled nodes
# Epoch: 42, Loss: 0.0164, Train: 100.00%, Valid: 50.40% Test: 53.40%
# Sampled 1333 nodes, 2034 edges, 140 labeled nodes
# Epoch: 43, Loss: 0.0177, Train: 100.00%, Valid: 50.40% Test: 53.40%
# Sampled 1346 nodes, 2067 edges, 140 labeled nodes
# Epoch: 44, Loss: 0.0133, Train: 100.00%, Valid: 50.80% Test: 53.50%
# Sampled 1295 nodes, 1941 edges, 140 labeled nodes
# Epoch: 45, Loss: 0.0032, Train: 100.00%, Valid: 50.20% Test: 53.60%
# Sampled 1336 nodes, 1996 edges, 140 labeled nodes
# Epoch: 46, Loss: 0.0364, Train: 100.00%, Valid: 49.80% Test: 53.10%
# Sampled 1265 nodes, 1931 edges, 140 labeled nodes
# Epoch: 47, Loss: 0.0042, Train: 100.00%, Valid: 49.60% Test: 53.10%
# Sampled 1321 nodes, 2016 edges, 140 labeled nodes
# Epoch: 48, Loss: 0.0067, Train: 100.00%, Valid: 49.60% Test: 52.80%
# Sampled 1316 nodes, 1956 edges, 140 labeled nodes
# Epoch: 49, Loss: 0.0157, Train: 100.00%, Valid: 49.40% Test: 52.60%
# Sampled 1292 nodes, 1922 edges, 140 labeled nodes
# Epoch: 50, Loss: 0.0056, Train: 100.00%, Valid: 49.00% Test: 52.60%
# Best model: Train: 100.00%, Valid: 53.80% Test: 55.20%

# %% [markdown]
# ## Sampling with Ratios 0.3

# %%
# Change the ratio to 0.3
args['ratios'] = (0.3, 0.3, 1)

graphs_train, graphs_val, graphs_test = \
    GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

graph_train = graphs_train[0]
graph_val = graphs_val[0]
graph_test = graphs_test[0]

model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
graphs = [graph_train, graph_val, graph_test]
batch_best_model, batch_accs_1 = train(graphs, graphs, args, model, optimizer)
train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], batch_best_model)
print('Best model:',
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * val_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Index fields: val_mask ignored.
# Index fields: test_mask ignored.
# Index fields: train_mask ignored.
# Sampled 392 nodes, 199 edges, 140 labeled nodes
# Epoch: 01, Loss: 2.0510, Train: 18.57%, Valid: 17.00% Test: 16.00%
# Sampled 429 nodes, 244 edges, 140 labeled nodes
# Epoch: 02, Loss: 1.9780, Train: 25.00%, Valid: 15.40% Test: 16.30%
# Sampled 435 nodes, 265 edges, 140 labeled nodes
# Epoch: 03, Loss: 1.9699, Train: 22.14%, Valid: 11.00% Test: 12.80%
# Sampled 377 nodes, 170 edges, 140 labeled nodes
# Epoch: 04, Loss: 1.8857, Train: 20.00%, Valid: 9.00% Test: 11.20%
# Sampled 388 nodes, 186 edges, 140 labeled nodes
# Epoch: 05, Loss: 1.8632, Train: 25.00%, Valid: 9.40% Test: 11.20%
# Sampled 423 nodes, 231 edges, 140 labeled nodes
# Epoch: 06, Loss: 1.8281, Train: 27.14%, Valid: 9.80% Test: 11.20%
# Sampled 419 nodes, 248 edges, 140 labeled nodes
# Epoch: 07, Loss: 1.8242, Train: 32.86%, Valid: 10.40% Test: 12.30%
# Sampled 396 nodes, 197 edges, 140 labeled nodes
# Epoch: 08, Loss: 1.8040, Train: 37.14%, Valid: 11.80% Test: 13.60%
# Sampled 425 nodes, 239 edges, 140 labeled nodes
# Epoch: 09, Loss: 1.7689, Train: 40.00%, Valid: 14.40% Test: 16.10%
# Sampled 384 nodes, 187 edges, 140 labeled nodes
# Epoch: 10, Loss: 1.8394, Train: 45.00%, Valid: 16.80% Test: 19.30%
# Sampled 395 nodes, 197 edges, 140 labeled nodes
# Epoch: 11, Loss: 1.7252, Train: 47.14%, Valid: 19.40% Test: 22.30%
# Sampled 443 nodes, 254 edges, 140 labeled nodes
# Epoch: 12, Loss: 1.7439, Train: 47.14%, Valid: 22.00% Test: 23.60%
# Sampled 412 nodes, 225 edges, 140 labeled nodes
# Epoch: 13, Loss: 1.7079, Train: 50.71%, Valid: 23.60% Test: 25.00%
# Sampled 412 nodes, 236 edges, 140 labeled nodes
# Epoch: 14, Loss: 1.6897, Train: 52.14%, Valid: 25.20% Test: 26.20%
# Sampled 355 nodes, 146 edges, 140 labeled nodes
# Epoch: 15, Loss: 1.7639, Train: 50.00%, Valid: 26.20% Test: 27.70%
# Sampled 411 nodes, 240 edges, 140 labeled nodes
# Epoch: 16, Loss: 1.6514, Train: 50.71%, Valid: 26.80% Test: 28.60%
# Sampled 373 nodes, 169 edges, 140 labeled nodes
# Epoch: 17, Loss: 1.6950, Train: 51.43%, Valid: 27.00% Test: 28.40%
# Sampled 446 nodes, 276 edges, 140 labeled nodes
# Epoch: 18, Loss: 1.7621, Train: 52.14%, Valid: 26.20% Test: 27.60%
# Sampled 372 nodes, 180 edges, 140 labeled nodes
# Epoch: 19, Loss: 1.5630, Train: 50.00%, Valid: 24.20% Test: 25.80%
# Sampled 456 nodes, 270 edges, 140 labeled nodes
# Epoch: 20, Loss: 1.6160, Train: 48.57%, Valid: 23.20% Test: 25.60%
# Sampled 445 nodes, 264 edges, 140 labeled nodes
# Epoch: 21, Loss: 1.7092, Train: 50.71%, Valid: 23.40% Test: 25.40%
# Sampled 478 nodes, 291 edges, 140 labeled nodes
# Epoch: 22, Loss: 1.7684, Train: 49.29%, Valid: 23.80% Test: 25.90%
# Sampled 441 nodes, 246 edges, 140 labeled nodes
# Epoch: 23, Loss: 1.7617, Train: 52.86%, Valid: 24.00% Test: 26.30%
# Sampled 448 nodes, 263 edges, 140 labeled nodes
# Epoch: 24, Loss: 1.7158, Train: 53.57%, Valid: 24.60% Test: 26.90%
# Sampled 419 nodes, 240 edges, 140 labeled nodes
# Epoch: 25, Loss: 1.5591, Train: 56.43%, Valid: 26.40% Test: 28.20%
# Sampled 426 nodes, 249 edges, 140 labeled nodes
# Epoch: 26, Loss: 1.4657, Train: 57.14%, Valid: 27.20% Test: 29.50%
# Sampled 421 nodes, 251 edges, 140 labeled nodes
# Epoch: 27, Loss: 1.6243, Train: 60.00%, Valid: 28.40% Test: 30.90%
# Sampled 432 nodes, 255 edges, 140 labeled nodes
# Epoch: 28, Loss: 1.5844, Train: 61.43%, Valid: 29.60% Test: 32.50%
# Sampled 398 nodes, 208 edges, 140 labeled nodes
# Epoch: 29, Loss: 1.5359, Train: 62.14%, Valid: 30.80% Test: 33.20%
# Sampled 415 nodes, 227 edges, 140 labeled nodes
# Epoch: 30, Loss: 1.7816, Train: 62.86%, Valid: 31.20% Test: 33.60%
# Sampled 410 nodes, 214 edges, 140 labeled nodes
# Epoch: 31, Loss: 1.6066, Train: 64.29%, Valid: 30.80% Test: 34.00%
# Sampled 421 nodes, 239 edges, 140 labeled nodes
# Epoch: 32, Loss: 1.4765, Train: 63.57%, Valid: 30.40% Test: 34.50%
# Sampled 408 nodes, 223 edges, 140 labeled nodes
# Epoch: 33, Loss: 1.4959, Train: 63.57%, Valid: 30.20% Test: 33.90%
# Sampled 416 nodes, 240 edges, 140 labeled nodes
# Epoch: 34, Loss: 1.5976, Train: 64.29%, Valid: 30.20% Test: 34.40%
# Sampled 373 nodes, 173 edges, 140 labeled nodes
# Epoch: 35, Loss: 1.4897, Train: 65.71%, Valid: 30.80% Test: 34.40%
# Sampled 467 nodes, 283 edges, 140 labeled nodes
# Epoch: 36, Loss: 1.6397, Train: 65.00%, Valid: 32.60% Test: 35.90%
# Sampled 407 nodes, 215 edges, 140 labeled nodes
# Epoch: 37, Loss: 1.6508, Train: 66.43%, Valid: 33.60% Test: 36.40%
# Sampled 383 nodes, 189 edges, 140 labeled nodes
# Epoch: 38, Loss: 1.5332, Train: 65.71%, Valid: 33.40% Test: 36.00%
# Sampled 447 nodes, 267 edges, 140 labeled nodes
# Epoch: 39, Loss: 1.6318, Train: 65.71%, Valid: 33.80% Test: 36.40%
# Sampled 383 nodes, 186 edges, 140 labeled nodes
# Epoch: 40, Loss: 1.4915, Train: 65.71%, Valid: 34.00% Test: 37.00%
# Sampled 392 nodes, 207 edges, 140 labeled nodes
# Epoch: 41, Loss: 1.5190, Train: 65.71%, Valid: 34.20% Test: 36.30%
# Sampled 400 nodes, 215 edges, 140 labeled nodes
# Epoch: 42, Loss: 1.3880, Train: 65.00%, Valid: 34.60% Test: 35.70%
# Sampled 424 nodes, 247 edges, 140 labeled nodes
# Epoch: 43, Loss: 1.5068, Train: 65.00%, Valid: 34.20% Test: 36.40%
# Sampled 397 nodes, 205 edges, 140 labeled nodes
# Epoch: 44, Loss: 1.5552, Train: 62.14%, Valid: 35.00% Test: 36.40%
# Sampled 459 nodes, 264 edges, 140 labeled nodes
# Epoch: 45, Loss: 1.5725, Train: 64.29%, Valid: 35.00% Test: 36.70%
# Sampled 342 nodes, 143 edges, 140 labeled nodes
# Epoch: 46, Loss: 1.5355, Train: 63.57%, Valid: 35.60% Test: 36.40%
# Sampled 444 nodes, 251 edges, 140 labeled nodes
# Epoch: 47, Loss: 1.5378, Train: 62.86%, Valid: 36.00% Test: 36.40%
# Sampled 413 nodes, 210 edges, 140 labeled nodes
# Epoch: 48, Loss: 1.5639, Train: 63.57%, Valid: 36.40% Test: 36.70%
# Sampled 427 nodes, 250 edges, 140 labeled nodes
# Epoch: 49, Loss: 1.4422, Train: 63.57%, Valid: 36.60% Test: 36.40%
# Sampled 417 nodes, 243 edges, 140 labeled nodes
# Epoch: 50, Loss: 1.5261, Train: 63.57%, Valid: 37.20% Test: 36.80%
# Best model: Train: 63.57%, Valid: 37.20% Test: 36.80%

# %% [markdown]
# ## Visualization

# %%
import numpy as np
from matplotlib import pyplot as plt

batch_results = np.array(batch_accs)
batch_results_1 = np.array(batch_accs_1)
all_results = np.array(all_accs)

x = np.arange(1, 51)

plt.figure(figsize=(9, 7))

plt.plot(x, batch_results[:, 0], label="Batch 0.8 Train")
plt.plot(x, batch_results[:, 1], label="Batch 0.8 Validation")
plt.plot(x, batch_results[:, 2], label="Batch 0.8 Test")
plt.plot(x, batch_results_1[:, 0], label="Batch 0.3 Train")
plt.plot(x, batch_results_1[:, 1], label="Batch 0.3 Validation")
plt.plot(x, batch_results_1[:, 2], label="Batch 0.3 Test")
plt.plot(x, all_results[:, 0], label="All Train")
plt.plot(x, all_results[:, 1], label="All Validation")
plt.plot(x, all_results[:, 2], label="All Test")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# Here all accuracies are evaluated on the full-batch mode.

# %% [markdown]
# # 3 Cluster Sampling
#
# Instead of the neighbor sampling, we can use another approach, subgraph (cluster) sampling, to scale up GNN. This approach is proposed in Cluster-GCN ([Chiang et al. (2019)](https://arxiv.org/abs/1905.07953)).
#
# In this section, we will implement vanilla Cluster-GCN and experiment with 3 different community partition algorithms.
#
# Notice that this section requires you have run the `Setup`, `GNN Model` and `Training and Testing` cells of the last section.

# %% [markdown]
# ## Setup

# %%
import copy
import torch
import random
import numpy as np
import networkx as nx
import torch.nn as nn
import torch.nn.functional as F
from community import community_louvain

from torch_geometric.nn import SAGEConv
from torch.utils.data import DataLoader
from torch_geometric.datasets import Planetoid
from torch.nn import Sequential, Linear, ReLU
from deepsnap.dataset import GraphDataset
from deepsnap.graph import Graph

pyg_dataset = Planetoid('./tmp', "Cora")

# %%
args = {
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'dropout': 0.5,
    'num_layers': 2,
    'hidden_size': 64,
    'lr': 0.005,
    'epochs': 150,
}

# %% [markdown]
# ## Partition the Graph into Clusters
#
# Here we use following three community detection / partition algorithms to partition the graph into different clusters:
# * [Kernighan–Lin algorithm (bisection)](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.community.kernighan_lin.kernighan_lin_bisection.html)
# * [Clauset-Newman-Moore greedy modularity maximization](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.community.modularity_max.greedy_modularity_communities.html#networkx.algorithms.community.modularity_max.greedy_modularity_communities)
# * [Louvain algorithm](https://python-louvain.readthedocs.io/en/latest/api.html)
#
#
# To make the training more stable, we discard the cluster that has less than 10 nodes.
#
# Let's first define these algorithms as DeepSNAP transformation on a graph.

# %%
# !pip install python-louvain
# Out:
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.10/dist-packages (0.16)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from python-louvain) (3.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-louvain) (1.23.5)

# %%
def preprocess(G, node_label_index, method="louvain"):
    graphs = []
    labeled_nodes = set(node_label_index.tolist())
    if method == "louvain":
        community_mapping = community_louvain.best_partition(G,resolution=10)
        communities = {}
        for node in community_mapping:
            comm = community_mapping[node]
            if comm in communities:
                communities[comm].add(node)
            else:
                communities[comm] = set([node])
        communities = communities.values()
    elif method == "bisection":
        communities = nx.algorithms.community.kernighan_lin_bisection(G)
    elif method == "greedy":
        communities = nx.algorithms.community.greedy_modularity_communities(G)

    for community in communities:
        nodes = set(community)
        subgraph = G.subgraph(nodes)
        # Make sure each subgraph has more than 10 nodes
        if subgraph.number_of_nodes() > 10:
            node_mapping = {node : i for i, node in enumerate(subgraph.nodes())}
            subgraph = nx.relabel_nodes(subgraph, node_mapping)
            # Get the id of the training set labeled node in the new graph
            train_label_index = []
            for node in labeled_nodes:
                if node in node_mapping:
                    # Append relabeled labeled node index
                    train_label_index.append(node_mapping[node])

            # Make sure the subgraph contains at least one training set labeled node
            if len(train_label_index) > 0:
                dg = Graph(subgraph)
                # Update node_label_index
                dg.node_label_index = torch.tensor(train_label_index, dtype=torch.long)
                graphs.append(dg)
    return graphs

# %% [markdown]
# ## Louvain Preprocess

# %%
graphs_train, graphs_val, graphs_test = \
    GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

graph_train = graphs_train[0]
graph_val = graphs_val[0]
graph_test = graphs_test[0]
graphs = preprocess(graph_train.G, graph_train.node_label_index, method="louvain")
print("Partition the graph in to {} communities".format(len(graphs)))
avg_num_nodes = 0
avg_num_edges = 0
for graph in graphs:
    avg_num_nodes += graph.num_nodes
    avg_num_edges += graph.num_edges
avg_num_nodes = int(avg_num_nodes / len(graphs))
avg_num_edges = int(avg_num_edges / len(graphs))
print("Each community has {} nodes in average".format(avg_num_nodes))
print("Each community has {} edges in average".format(avg_num_edges))
# Out:
# Index fields: val_mask ignored.
# Index fields: test_mask ignored.
# Index fields: train_mask ignored.
# Partition the graph in to 73 communities
# Each community has 21 nodes in average
# Each community has 31 edges in average

# %% [markdown]
# ## Louvain Training

# %%
model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
louvain_best_model, louvain_accs = train(graphs, [graph_train, graph_val, graph_test], args, model, optimizer, mode="community")
train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], louvain_best_model)
print('Best model:',
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * val_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 1.6977, Train: 14.29%, Valid: 7.20% Test: 9.00%
# Epoch: 02, Loss: 2.1334, Train: 14.29%, Valid: 7.40% Test: 9.30%
# Epoch: 03, Loss: 1.8576, Train: 19.29%, Valid: 10.40% Test: 11.40%
# Epoch: 04, Loss: 2.4256, Train: 18.57%, Valid: 14.80% Test: 15.60%
# Epoch: 05, Loss: 1.9947, Train: 17.86%, Valid: 16.60% Test: 18.00%
# Epoch: 06, Loss: 2.0199, Train: 16.43%, Valid: 21.80% Test: 22.60%
# Epoch: 07, Loss: 0.5907, Train: 16.43%, Valid: 22.00% Test: 22.90%
# Epoch: 08, Loss: 2.3234, Train: 17.86%, Valid: 20.40% Test: 21.50%
# Epoch: 09, Loss: 3.6180, Train: 17.86%, Valid: 20.20% Test: 22.00%
# Epoch: 10, Loss: 1.3273, Train: 17.86%, Valid: 20.20% Test: 21.10%
# Epoch: 11, Loss: 2.3334, Train: 20.00%, Valid: 18.60% Test: 19.80%
# Epoch: 12, Loss: 2.3501, Train: 19.29%, Valid: 18.80% Test: 19.60%
# Epoch: 13, Loss: 0.9372, Train: 19.29%, Valid: 19.00% Test: 19.10%
# Epoch: 14, Loss: 3.2524, Train: 20.71%, Valid: 16.20% Test: 17.60%
# Epoch: 15, Loss: 2.0669, Train: 20.00%, Valid: 17.60% Test: 18.20%
# Epoch: 16, Loss: 2.0479, Train: 20.00%, Valid: 17.20% Test: 18.40%
# Epoch: 17, Loss: 2.1885, Train: 20.71%, Valid: 16.60% Test: 18.40%
# Epoch: 18, Loss: 2.3358, Train: 22.14%, Valid: 16.20% Test: 17.90%
# Epoch: 19, Loss: 3.0653, Train: 21.43%, Valid: 15.00% Test: 17.10%
# Epoch: 20, Loss: 3.1830, Train: 22.14%, Valid: 13.60% Test: 14.00%
# Epoch: 21, Loss: 3.7490, Train: 22.86%, Valid: 13.00% Test: 13.40%
# Epoch: 22, Loss: 1.1652, Train: 23.57%, Valid: 12.40% Test: 13.50%
# Epoch: 23, Loss: 1.2140, Train: 24.29%, Valid: 13.40% Test: 14.20%
# Epoch: 24, Loss: 3.0696, Train: 22.86%, Valid: 14.80% Test: 14.90%
# Epoch: 25, Loss: 1.7845, Train: 23.57%, Valid: 15.60% Test: 15.00%
# Epoch: 26, Loss: 1.9699, Train: 25.71%, Valid: 16.40% Test: 16.00%
# Epoch: 27, Loss: 0.4578, Train: 26.43%, Valid: 16.60% Test: 16.80%
# Epoch: 28, Loss: 1.4356, Train: 26.43%, Valid: 18.20% Test: 17.50%
# Epoch: 29, Loss: 2.0866, Train: 27.86%, Valid: 19.20% Test: 18.00%
# Epoch: 30, Loss: 3.0924, Train: 30.71%, Valid: 19.40% Test: 18.20%
# Epoch: 31, Loss: 0.6897, Train: 28.57%, Valid: 18.60% Test: 17.50%
# Epoch: 32, Loss: 3.2695, Train: 29.29%, Valid: 20.00% Test: 19.20%
# Epoch: 33, Loss: 3.1179, Train: 30.00%, Valid: 20.20% Test: 18.70%
# Epoch: 34, Loss: 2.9841, Train: 28.57%, Valid: 20.00% Test: 18.20%
# Epoch: 35, Loss: 1.8153, Train: 28.57%, Valid: 19.00% Test: 18.20%
# Epoch: 36, Loss: 1.9755, Train: 27.14%, Valid: 18.80% Test: 18.80%
# Epoch: 37, Loss: 0.1971, Train: 27.14%, Valid: 18.40% Test: 19.50%
# Epoch: 38, Loss: 2.7791, Train: 27.14%, Valid: 18.40% Test: 19.80%
# Epoch: 39, Loss: 0.2683, Train: 26.43%, Valid: 22.20% Test: 20.90%
# Epoch: 40, Loss: 1.3344, Train: 28.57%, Valid: 20.00% Test: 20.30%
# Epoch: 41, Loss: 0.8232, Train: 28.57%, Valid: 18.20% Test: 18.60%
# Epoch: 42, Loss: 0.8694, Train: 30.71%, Valid: 18.20% Test: 17.70%
# Epoch: 43, Loss: 2.5688, Train: 30.71%, Valid: 17.80% Test: 17.20%
# Epoch: 44, Loss: 3.0634, Train: 29.29%, Valid: 17.80% Test: 17.20%
# Epoch: 45, Loss: 0.1671, Train: 27.86%, Valid: 18.20% Test: 17.40%
# Epoch: 46, Loss: 2.0061, Train: 28.57%, Valid: 18.60% Test: 17.80%
# Epoch: 47, Loss: 1.4480, Train: 31.43%, Valid: 18.20% Test: 17.60%
# Epoch: 48, Loss: 0.9261, Train: 30.71%, Valid: 19.60% Test: 17.70%
# Epoch: 49, Loss: 1.8060, Train: 32.86%, Valid: 18.60% Test: 17.00%
# Epoch: 50, Loss: 2.5321, Train: 35.71%, Valid: 17.60% Test: 16.60%
# Epoch: 51, Loss: 1.0158, Train: 36.43%, Valid: 17.20% Test: 16.50%
# Epoch: 52, Loss: 1.7370, Train: 36.43%, Valid: 17.80% Test: 16.20%
# Epoch: 53, Loss: 0.5512, Train: 38.57%, Valid: 17.00% Test: 15.90%
# Epoch: 54, Loss: 2.7254, Train: 40.00%, Valid: 16.40% Test: 16.50%
# Epoch: 55, Loss: 1.7003, Train: 42.14%, Valid: 16.40% Test: 16.30%
# Epoch: 56, Loss: 3.2915, Train: 42.86%, Valid: 15.80% Test: 15.50%
# Epoch: 57, Loss: 1.0003, Train: 43.57%, Valid: 15.00% Test: 15.10%
# Epoch: 58, Loss: 1.7248, Train: 45.00%, Valid: 14.20% Test: 15.00%
# Epoch: 59, Loss: 1.4728, Train: 47.14%, Valid: 13.40% Test: 14.90%
# Epoch: 60, Loss: 0.0686, Train: 47.86%, Valid: 13.60% Test: 13.90%
# Epoch: 61, Loss: 2.6753, Train: 51.43%, Valid: 12.80% Test: 14.50%
# Epoch: 62, Loss: 0.6291, Train: 50.00%, Valid: 12.60% Test: 14.50%
# Epoch: 63, Loss: 2.4758, Train: 49.29%, Valid: 12.20% Test: 14.10%
# Epoch: 64, Loss: 0.0145, Train: 48.57%, Valid: 12.20% Test: 15.10%
# Epoch: 65, Loss: 1.6438, Train: 49.29%, Valid: 11.20% Test: 14.50%
# Epoch: 66, Loss: 0.7891, Train: 50.00%, Valid: 10.20% Test: 13.80%
# Epoch: 67, Loss: 2.2074, Train: 49.29%, Valid: 10.00% Test: 12.20%
# Epoch: 68, Loss: 0.3870, Train: 48.57%, Valid: 10.00% Test: 11.80%
# Epoch: 69, Loss: 2.3846, Train: 47.86%, Valid: 9.00% Test: 11.10%
# Epoch: 70, Loss: 1.9987, Train: 49.29%, Valid: 7.60% Test: 10.70%
# Epoch: 71, Loss: 2.0195, Train: 49.29%, Valid: 7.00% Test: 11.10%
# Epoch: 72, Loss: 2.4449, Train: 48.57%, Valid: 7.00% Test: 10.40%
# Epoch: 73, Loss: 0.4992, Train: 50.00%, Valid: 6.60% Test: 10.20%
# Epoch: 74, Loss: 5.8638, Train: 47.86%, Valid: 6.00% Test: 9.70%
# Epoch: 75, Loss: 0.7564, Train: 45.71%, Valid: 6.00% Test: 9.60%
# Epoch: 76, Loss: 0.3252, Train: 47.14%, Valid: 5.80% Test: 9.90%
# Epoch: 77, Loss: 2.0529, Train: 47.14%, Valid: 6.20% Test: 9.60%
# Epoch: 78, Loss: 0.2362, Train: 47.14%, Valid: 5.60% Test: 9.20%
# Epoch: 79, Loss: 3.8164, Train: 48.57%, Valid: 6.40% Test: 9.50%
# Epoch: 80, Loss: 1.8985, Train: 50.00%, Valid: 7.00% Test: 10.80%
# Epoch: 81, Loss: 0.8088, Train: 50.00%, Valid: 7.20% Test: 11.00%
# Epoch: 82, Loss: 3.5438, Train: 50.71%, Valid: 8.00% Test: 12.00%
# Epoch: 83, Loss: 1.3130, Train: 47.86%, Valid: 11.60% Test: 13.20%
# Epoch: 84, Loss: 0.0261, Train: 47.14%, Valid: 12.40% Test: 14.20%
# Epoch: 85, Loss: 0.1956, Train: 45.71%, Valid: 14.40% Test: 15.50%
# Epoch: 86, Loss: 2.1300, Train: 46.43%, Valid: 15.00% Test: 16.40%
# Epoch: 87, Loss: 1.2090, Train: 47.86%, Valid: 15.40% Test: 17.10%
# Epoch: 88, Loss: 0.8261, Train: 47.86%, Valid: 16.60% Test: 16.50%
# Epoch: 89, Loss: 0.1740, Train: 47.86%, Valid: 17.40% Test: 18.70%
# Epoch: 90, Loss: 0.4227, Train: 46.43%, Valid: 17.60% Test: 18.30%
# Epoch: 91, Loss: 0.8117, Train: 46.43%, Valid: 17.80% Test: 18.20%
# Epoch: 92, Loss: 0.4162, Train: 45.71%, Valid: 18.40% Test: 18.50%
# Epoch: 93, Loss: 0.0013, Train: 45.71%, Valid: 19.60% Test: 19.50%
# Epoch: 94, Loss: 0.8362, Train: 45.00%, Valid: 18.80% Test: 18.80%
# Epoch: 95, Loss: 0.3511, Train: 46.43%, Valid: 18.60% Test: 18.20%
# Epoch: 96, Loss: 2.2486, Train: 46.43%, Valid: 19.00% Test: 18.10%
# Epoch: 97, Loss: 0.0203, Train: 46.43%, Valid: 19.80% Test: 19.20%
# Epoch: 98, Loss: 1.2191, Train: 45.71%, Valid: 19.40% Test: 19.40%
# Epoch: 99, Loss: 1.6913, Train: 45.71%, Valid: 19.00% Test: 18.20%
# Epoch: 100, Loss: 0.0305, Train: 46.43%, Valid: 18.60% Test: 18.10%
# Epoch: 101, Loss: 0.3229, Train: 47.14%, Valid: 19.20% Test: 18.20%
# Epoch: 102, Loss: 0.1809, Train: 47.14%, Valid: 19.00% Test: 18.20%
# Epoch: 103, Loss: 0.0069, Train: 48.57%, Valid: 18.20% Test: 18.20%
# Epoch: 104, Loss: 1.4105, Train: 49.29%, Valid: 19.40% Test: 18.40%
# Epoch: 105, Loss: 2.1872, Train: 48.57%, Valid: 19.40% Test: 19.50%
# Epoch: 106, Loss: 0.1581, Train: 50.00%, Valid: 19.20% Test: 18.80%
# Epoch: 107, Loss: 0.1387, Train: 50.71%, Valid: 20.40% Test: 19.40%
# Epoch: 108, Loss: 1.1874, Train: 51.43%, Valid: 19.80% Test: 18.60%
# Epoch: 109, Loss: 0.0130, Train: 52.86%, Valid: 17.80% Test: 18.80%
# Epoch: 110, Loss: 2.1871, Train: 52.86%, Valid: 17.80% Test: 18.30%
# Epoch: 111, Loss: 1.6703, Train: 53.57%, Valid: 17.80% Test: 18.40%
# Epoch: 112, Loss: 0.0903, Train: 55.00%, Valid: 17.60% Test: 18.60%
# Epoch: 113, Loss: 3.3992, Train: 55.71%, Valid: 15.80% Test: 17.70%
# Epoch: 114, Loss: 0.1603, Train: 57.14%, Valid: 16.20% Test: 16.80%
# Epoch: 115, Loss: 1.4523, Train: 57.14%, Valid: 16.00% Test: 16.70%
# Epoch: 116, Loss: 0.4223, Train: 57.86%, Valid: 15.80% Test: 15.90%
# Epoch: 117, Loss: 0.3346, Train: 60.00%, Valid: 16.40% Test: 16.50%
# Epoch: 118, Loss: 0.7164, Train: 59.29%, Valid: 17.00% Test: 17.30%
# Epoch: 119, Loss: 0.0055, Train: 60.00%, Valid: 17.80% Test: 17.00%
# Epoch: 120, Loss: 0.0702, Train: 60.71%, Valid: 17.60% Test: 17.10%
# Epoch: 121, Loss: 0.1470, Train: 60.71%, Valid: 17.20% Test: 16.00%
# Epoch: 122, Loss: 0.1181, Train: 60.71%, Valid: 17.60% Test: 16.80%
# Epoch: 123, Loss: 0.7061, Train: 62.14%, Valid: 16.80% Test: 15.80%
# Epoch: 124, Loss: 2.8741, Train: 62.14%, Valid: 16.60% Test: 16.40%
# Epoch: 125, Loss: 0.6080, Train: 62.14%, Valid: 17.20% Test: 16.50%
# Epoch: 126, Loss: 0.0024, Train: 62.14%, Valid: 16.40% Test: 15.90%
# Epoch: 127, Loss: 1.5978, Train: 63.57%, Valid: 16.20% Test: 15.70%
# Epoch: 128, Loss: 0.0321, Train: 65.00%, Valid: 15.60% Test: 15.60%
# Epoch: 129, Loss: 0.2033, Train: 64.29%, Valid: 14.60% Test: 14.90%
# Epoch: 130, Loss: 0.0080, Train: 63.57%, Valid: 14.60% Test: 14.90%
# Epoch: 131, Loss: 0.0012, Train: 63.57%, Valid: 14.60% Test: 14.70%
# Epoch: 132, Loss: 0.0303, Train: 65.00%, Valid: 16.00% Test: 15.40%
# Epoch: 133, Loss: 0.1273, Train: 64.29%, Valid: 15.80% Test: 15.80%
# Epoch: 134, Loss: 0.1825, Train: 64.29%, Valid: 16.60% Test: 15.90%
# Epoch: 135, Loss: 0.2929, Train: 63.57%, Valid: 16.40% Test: 16.90%
# Epoch: 136, Loss: 0.7800, Train: 62.86%, Valid: 16.80% Test: 16.70%
# Epoch: 137, Loss: 0.0156, Train: 64.29%, Valid: 18.40% Test: 19.20%
# Epoch: 138, Loss: 0.0046, Train: 64.29%, Valid: 17.60% Test: 18.20%
# Epoch: 139, Loss: 2.9977, Train: 65.71%, Valid: 18.40% Test: 19.00%
# Epoch: 140, Loss: 0.1305, Train: 65.71%, Valid: 20.20% Test: 18.70%
# Epoch: 141, Loss: 0.6099, Train: 62.86%, Valid: 20.40% Test: 18.20%
# Epoch: 142, Loss: 0.2541, Train: 62.86%, Valid: 20.60% Test: 18.70%
# Epoch: 143, Loss: 0.4551, Train: 63.57%, Valid: 21.20% Test: 18.60%
# Epoch: 144, Loss: 0.0140, Train: 62.14%, Valid: 21.20% Test: 20.20%
# Epoch: 145, Loss: 0.6612, Train: 62.14%, Valid: 21.20% Test: 19.80%
# Epoch: 146, Loss: 1.0608, Train: 63.57%, Valid: 20.00% Test: 19.60%
# Epoch: 147, Loss: 0.1440, Train: 62.86%, Valid: 19.60% Test: 19.10%
# Epoch: 148, Loss: 0.0070, Train: 64.29%, Valid: 19.00% Test: 19.20%
# Epoch: 149, Loss: 1.3333, Train: 65.71%, Valid: 18.80% Test: 18.30%
# Epoch: 150, Loss: 0.8219, Train: 64.29%, Valid: 19.20% Test: 18.60%
# Best model: Train: 26.43%, Valid: 22.20% Test: 20.90%

# %% [markdown]
# ## Bisection Preprocess

# %%
graphs_train, graphs_val, graphs_test = \
    GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

graph_train = graphs_train[0]
graph_val = graphs_val[0]
graph_test = graphs_test[0]
graphs = preprocess(graph_train.G, graph_train.node_label_index, method="bisection")
print("Partition the graph in to {} communities".format(len(graphs)))
avg_num_nodes = 0
avg_num_edges = 0
for graph in graphs:
    avg_num_nodes += graph.num_nodes
    avg_num_edges += graph.num_edges
avg_num_nodes = int(avg_num_nodes / len(graphs))
avg_num_edges = int(avg_num_edges / len(graphs))
print("Each community has {} nodes in average".format(avg_num_nodes))
print("Each community has {} edges in average".format(avg_num_edges))
# Out:
# Index fields: val_mask ignored.
# Index fields: test_mask ignored.
# Index fields: train_mask ignored.
# Partition the graph in to 2 communities
# Each community has 1354 nodes in average
# Each community has 2378 edges in average

# %% [markdown]
# ## Bisection Training

# %%
model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
bisection_best_model, bisection_accs = train(graphs, [graph_train, graph_val, graph_test], args, model, optimizer, mode="community")
train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], bisection_best_model)
print('Best model:',
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * val_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 1.9637, Train: 42.86%, Valid: 15.00% Test: 17.70%
# Epoch: 02, Loss: 1.9127, Train: 80.00%, Valid: 34.60% Test: 34.50%
# Epoch: 03, Loss: 1.2287, Train: 95.71%, Valid: 46.60% Test: 49.20%
# Epoch: 04, Loss: 0.6390, Train: 99.29%, Valid: 58.60% Test: 61.00%
# Epoch: 05, Loss: 0.4890, Train: 99.29%, Valid: 66.40% Test: 68.00%
# Epoch: 06, Loss: 0.2189, Train: 99.29%, Valid: 69.20% Test: 71.40%
# Epoch: 07, Loss: 0.2421, Train: 99.29%, Valid: 71.80% Test: 72.90%
# Epoch: 08, Loss: 0.1812, Train: 99.29%, Valid: 73.20% Test: 73.60%
# Epoch: 09, Loss: 0.0903, Train: 100.00%, Valid: 74.40% Test: 74.60%
# Epoch: 10, Loss: 0.0339, Train: 100.00%, Valid: 75.20% Test: 74.40%
# Epoch: 11, Loss: 0.0268, Train: 100.00%, Valid: 75.20% Test: 74.70%
# Epoch: 12, Loss: 0.0196, Train: 100.00%, Valid: 75.20% Test: 74.70%
# Epoch: 13, Loss: 0.0063, Train: 100.00%, Valid: 74.60% Test: 74.70%
# Epoch: 14, Loss: 0.0054, Train: 100.00%, Valid: 74.60% Test: 74.90%
# Epoch: 15, Loss: 0.0133, Train: 100.00%, Valid: 74.80% Test: 74.20%
# Epoch: 16, Loss: 0.0107, Train: 100.00%, Valid: 74.80% Test: 74.30%
# Epoch: 17, Loss: 0.0039, Train: 100.00%, Valid: 74.60% Test: 74.30%
# Epoch: 18, Loss: 0.0039, Train: 100.00%, Valid: 74.40% Test: 74.30%
# Epoch: 19, Loss: 0.0025, Train: 100.00%, Valid: 74.00% Test: 74.70%
# Epoch: 20, Loss: 0.0088, Train: 100.00%, Valid: 73.80% Test: 74.40%
# Epoch: 21, Loss: 0.0008, Train: 100.00%, Valid: 74.40% Test: 74.20%
# Epoch: 22, Loss: 0.0017, Train: 100.00%, Valid: 74.20% Test: 74.10%
# Epoch: 23, Loss: 0.0042, Train: 100.00%, Valid: 74.20% Test: 74.40%
# Epoch: 24, Loss: 0.0007, Train: 100.00%, Valid: 73.80% Test: 74.40%
# Epoch: 25, Loss: 0.0004, Train: 100.00%, Valid: 73.60% Test: 74.50%
# Epoch: 26, Loss: 0.0023, Train: 100.00%, Valid: 73.60% Test: 74.50%
# Epoch: 27, Loss: 0.0004, Train: 100.00%, Valid: 73.20% Test: 74.50%
# Epoch: 28, Loss: 0.0005, Train: 100.00%, Valid: 73.20% Test: 74.40%
# Epoch: 29, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 30, Loss: 0.0004, Train: 100.00%, Valid: 72.80% Test: 74.30%
# Epoch: 31, Loss: 0.0008, Train: 100.00%, Valid: 72.80% Test: 74.30%
# Epoch: 32, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 33, Loss: 0.0009, Train: 100.00%, Valid: 73.20% Test: 74.40%
# Epoch: 34, Loss: 0.0004, Train: 100.00%, Valid: 73.40% Test: 74.70%
# Epoch: 35, Loss: 0.0011, Train: 100.00%, Valid: 73.20% Test: 74.60%
# Epoch: 36, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 37, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 38, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 74.30%
# Epoch: 39, Loss: 0.0001, Train: 100.00%, Valid: 72.80% Test: 74.20%
# Epoch: 40, Loss: 0.0012, Train: 100.00%, Valid: 72.80% Test: 74.20%
# Epoch: 41, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 42, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 43, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.50%
# Epoch: 44, Loss: 0.0006, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 45, Loss: 0.0012, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 46, Loss: 0.0009, Train: 100.00%, Valid: 73.00% Test: 74.20%
# Epoch: 47, Loss: 0.0004, Train: 100.00%, Valid: 72.80% Test: 74.10%
# Epoch: 48, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 74.20%
# Epoch: 49, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 50, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 74.20%
# Epoch: 51, Loss: 0.0005, Train: 100.00%, Valid: 73.00% Test: 74.30%
# Epoch: 52, Loss: 0.0130, Train: 100.00%, Valid: 73.00% Test: 74.30%
# Epoch: 53, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 74.30%
# Epoch: 54, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 74.40%
# Epoch: 55, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 74.60%
# Epoch: 56, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 74.60%
# Epoch: 57, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 74.70%
# Epoch: 58, Loss: 0.0006, Train: 100.00%, Valid: 73.40% Test: 74.80%
# Epoch: 59, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 74.80%
# Epoch: 60, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 74.70%
# Epoch: 61, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 74.80%
# Epoch: 62, Loss: 0.0008, Train: 100.00%, Valid: 73.40% Test: 74.80%
# Epoch: 63, Loss: 0.0004, Train: 100.00%, Valid: 73.20% Test: 74.80%
# Epoch: 64, Loss: 0.0017, Train: 100.00%, Valid: 73.40% Test: 74.90%
# Epoch: 65, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 74.90%
# Epoch: 66, Loss: 0.0005, Train: 100.00%, Valid: 73.60% Test: 74.80%
# Epoch: 67, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 74.70%
# Epoch: 68, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 74.80%
# Epoch: 69, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 74.60%
# Epoch: 70, Loss: 0.0001, Train: 100.00%, Valid: 73.80% Test: 74.70%
# Epoch: 71, Loss: 0.0001, Train: 100.00%, Valid: 73.80% Test: 74.80%
# Epoch: 72, Loss: 0.0003, Train: 100.00%, Valid: 73.60% Test: 74.60%
# Epoch: 73, Loss: 0.0081, Train: 100.00%, Valid: 73.80% Test: 74.80%
# Epoch: 74, Loss: 0.0008, Train: 100.00%, Valid: 74.00% Test: 74.90%
# Epoch: 75, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 74.90%
# Epoch: 76, Loss: 0.0004, Train: 100.00%, Valid: 73.80% Test: 74.90%
# Epoch: 77, Loss: 0.0001, Train: 100.00%, Valid: 73.80% Test: 74.70%
# Epoch: 78, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 74.70%
# Epoch: 79, Loss: 0.0000, Train: 100.00%, Valid: 73.60% Test: 74.60%
# Epoch: 80, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 74.60%
# Epoch: 81, Loss: 0.0072, Train: 100.00%, Valid: 73.60% Test: 74.60%
# Epoch: 82, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 74.80%
# Epoch: 83, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 74.60%
# Epoch: 84, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 74.60%
# Epoch: 85, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 86, Loss: 0.0020, Train: 100.00%, Valid: 73.20% Test: 74.80%
# Epoch: 87, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 88, Loss: 0.0007, Train: 100.00%, Valid: 72.80% Test: 74.60%
# Epoch: 89, Loss: 0.0020, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 90, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.50%
# Epoch: 91, Loss: 0.0013, Train: 100.00%, Valid: 73.00% Test: 74.50%
# Epoch: 92, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 74.50%
# Epoch: 93, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 74.60%
# Epoch: 94, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 74.50%
# Epoch: 95, Loss: 0.0001, Train: 100.00%, Valid: 72.80% Test: 74.60%
# Epoch: 96, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 74.80%
# Epoch: 97, Loss: 0.0011, Train: 100.00%, Valid: 72.80% Test: 74.70%
# Epoch: 98, Loss: 0.0001, Train: 100.00%, Valid: 72.80% Test: 74.80%
# Epoch: 99, Loss: 0.0001, Train: 100.00%, Valid: 72.80% Test: 74.80%
# Epoch: 100, Loss: 0.0004, Train: 100.00%, Valid: 72.80% Test: 74.50%
# Epoch: 101, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 74.50%
# Epoch: 102, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.70%
# Epoch: 103, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 74.70%
# Epoch: 104, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 74.70%
# Epoch: 105, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.70%
# Epoch: 106, Loss: 0.0004, Train: 100.00%, Valid: 73.20% Test: 74.70%
# Epoch: 107, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 74.50%
# Epoch: 108, Loss: 0.0025, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 109, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 110, Loss: 0.0006, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 111, Loss: 0.0008, Train: 100.00%, Valid: 72.60% Test: 74.50%
# Epoch: 112, Loss: 0.0004, Train: 100.00%, Valid: 72.60% Test: 74.50%
# Epoch: 113, Loss: 0.0000, Train: 100.00%, Valid: 72.60% Test: 74.40%
# Epoch: 114, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 74.50%
# Epoch: 115, Loss: 0.0006, Train: 100.00%, Valid: 72.80% Test: 74.40%
# Epoch: 116, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.50%
# Epoch: 117, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.50%
# Epoch: 118, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 119, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 120, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 74.50%
# Epoch: 121, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 122, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 74.50%
# Epoch: 123, Loss: 0.0006, Train: 100.00%, Valid: 73.00% Test: 74.50%
# Epoch: 124, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 74.60%
# Epoch: 125, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 74.60%
# Epoch: 126, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 74.70%
# Epoch: 127, Loss: 0.0001, Train: 100.00%, Valid: 72.80% Test: 74.60%
# Epoch: 128, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 129, Loss: 0.0005, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 130, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.70%
# Epoch: 131, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 132, Loss: 0.0003, Train: 100.00%, Valid: 73.00% Test: 74.70%
# Epoch: 133, Loss: 0.0002, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 134, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 135, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.80%
# Epoch: 136, Loss: 0.0000, Train: 100.00%, Valid: 73.00% Test: 74.70%
# Epoch: 137, Loss: 0.0011, Train: 100.00%, Valid: 73.20% Test: 74.70%
# Epoch: 138, Loss: 0.0009, Train: 100.00%, Valid: 73.40% Test: 74.80%
# Epoch: 139, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 74.70%
# Epoch: 140, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 74.80%
# Epoch: 141, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 74.70%
# Epoch: 142, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 74.90%
# Epoch: 143, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 75.00%
# Epoch: 144, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 75.00%
# Epoch: 145, Loss: 0.0001, Train: 100.00%, Valid: 73.20% Test: 75.00%
# Epoch: 146, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 75.10%
# Epoch: 147, Loss: 0.0009, Train: 100.00%, Valid: 73.20% Test: 75.00%
# Epoch: 148, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.10%
# Epoch: 149, Loss: 0.0002, Train: 100.00%, Valid: 73.20% Test: 75.00%
# Epoch: 150, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.10%
# Best model: Train: 100.00%, Valid: 75.20% Test: 74.40%

# %% [markdown]
# ## Greedy Preprocess

# %%
graphs_train, graphs_val, graphs_test = \
    GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

graph_train = graphs_train[0]
graph_val = graphs_val[0]
graph_test = graphs_test[0]
graphs = preprocess(graph_train.G, graph_train.node_label_index, method="greedy")
print("Partition the graph in to {} communities".format(len(graphs)))
avg_num_nodes = 0
avg_num_edges = 0
for graph in graphs:
    avg_num_nodes += graph.num_nodes
    avg_num_edges += graph.num_edges
avg_num_nodes = int(avg_num_nodes / len(graphs))
avg_num_edges = int(avg_num_edges / len(graphs))
print("Each community has {} nodes in average".format(avg_num_nodes))
print("Each community has {} edges in average".format(avg_num_edges))
# Out:
# Index fields: val_mask ignored.
# Index fields: test_mask ignored.
# Index fields: train_mask ignored.
# Partition the graph in to 20 communities
# Each community has 121 nodes in average
# Each community has 222 edges in average

# %% [markdown]
# ## Greedy Training

# %%
model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
greedy_best_model, greedy_accs = train(graphs, [graph_train, graph_val, graph_test], args, model, optimizer, mode="community")
train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], greedy_best_model)
print('Best model:',
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * val_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Epoch: 01, Loss: 2.1322, Train: 10.71%, Valid: 27.00% Test: 25.10%
# Epoch: 02, Loss: 2.6835, Train: 14.29%, Valid: 31.60% Test: 31.80%
# Epoch: 03, Loss: 0.5201, Train: 15.00%, Valid: 31.60% Test: 31.90%
# Epoch: 04, Loss: 1.1225, Train: 15.71%, Valid: 31.60% Test: 31.80%
# Epoch: 05, Loss: 2.1468, Train: 18.57%, Valid: 30.20% Test: 30.00%
# Epoch: 06, Loss: 2.1011, Train: 16.43%, Valid: 26.60% Test: 27.30%
# Epoch: 07, Loss: 2.3696, Train: 16.43%, Valid: 23.80% Test: 25.10%
# Epoch: 08, Loss: 1.2240, Train: 18.57%, Valid: 22.40% Test: 23.30%
# Epoch: 09, Loss: 2.8554, Train: 19.29%, Valid: 21.20% Test: 23.10%
# Epoch: 10, Loss: 0.6986, Train: 22.86%, Valid: 21.00% Test: 23.20%
# Epoch: 11, Loss: 0.7046, Train: 25.00%, Valid: 20.80% Test: 22.90%
# Epoch: 12, Loss: 0.2578, Train: 25.71%, Valid: 20.60% Test: 22.80%
# Epoch: 13, Loss: 3.8368, Train: 27.86%, Valid: 22.00% Test: 22.70%
# Epoch: 14, Loss: 0.5735, Train: 30.00%, Valid: 21.00% Test: 23.00%
# Epoch: 15, Loss: 1.9284, Train: 32.14%, Valid: 19.40% Test: 22.60%
# Epoch: 16, Loss: 0.4493, Train: 37.86%, Valid: 16.00% Test: 21.40%
# Epoch: 17, Loss: 2.3551, Train: 39.29%, Valid: 16.40% Test: 21.70%
# Epoch: 18, Loss: 1.5677, Train: 38.57%, Valid: 19.20% Test: 21.70%
# Epoch: 19, Loss: 1.2908, Train: 41.43%, Valid: 22.20% Test: 22.50%
# Epoch: 20, Loss: 0.3616, Train: 40.00%, Valid: 22.20% Test: 22.40%
# Epoch: 21, Loss: 1.3207, Train: 39.29%, Valid: 23.60% Test: 22.60%
# Epoch: 22, Loss: 0.2427, Train: 38.57%, Valid: 24.20% Test: 23.60%
# Epoch: 23, Loss: 0.3961, Train: 37.14%, Valid: 23.20% Test: 24.40%
# Epoch: 24, Loss: 0.7576, Train: 37.86%, Valid: 23.60% Test: 24.70%
# Epoch: 25, Loss: 1.0089, Train: 37.86%, Valid: 22.80% Test: 25.00%
# Epoch: 26, Loss: 0.0648, Train: 38.57%, Valid: 23.40% Test: 25.00%
# Epoch: 27, Loss: 0.1811, Train: 36.43%, Valid: 26.20% Test: 26.20%
# Epoch: 28, Loss: 0.7664, Train: 37.86%, Valid: 24.60% Test: 25.90%
# Epoch: 29, Loss: 0.0409, Train: 37.14%, Valid: 24.20% Test: 26.80%
# Epoch: 30, Loss: 0.5250, Train: 36.43%, Valid: 22.40% Test: 27.30%
# Epoch: 31, Loss: 0.0384, Train: 37.14%, Valid: 25.20% Test: 27.30%
# Epoch: 32, Loss: 3.4972, Train: 39.29%, Valid: 24.80% Test: 28.10%
# Epoch: 33, Loss: 5.1128, Train: 40.00%, Valid: 24.00% Test: 28.00%
# Epoch: 34, Loss: 1.3972, Train: 42.14%, Valid: 23.40% Test: 28.20%
# Epoch: 35, Loss: 2.7974, Train: 45.71%, Valid: 24.00% Test: 28.30%
# Epoch: 36, Loss: 1.6726, Train: 50.00%, Valid: 24.40% Test: 29.10%
# Epoch: 37, Loss: 3.1524, Train: 55.00%, Valid: 25.00% Test: 29.50%
# Epoch: 38, Loss: 0.0000, Train: 55.71%, Valid: 26.00% Test: 30.10%
# Epoch: 39, Loss: 0.7775, Train: 57.14%, Valid: 25.80% Test: 29.80%
# Epoch: 40, Loss: 0.0956, Train: 57.86%, Valid: 26.40% Test: 30.10%
# Epoch: 41, Loss: 2.0219, Train: 58.57%, Valid: 26.40% Test: 29.70%
# Epoch: 42, Loss: 3.1420, Train: 58.57%, Valid: 27.00% Test: 30.00%
# Epoch: 43, Loss: 0.5088, Train: 59.29%, Valid: 25.80% Test: 28.90%
# Epoch: 44, Loss: 0.1223, Train: 59.29%, Valid: 25.60% Test: 28.90%
# Epoch: 45, Loss: 0.0189, Train: 61.43%, Valid: 25.00% Test: 27.70%
# Epoch: 46, Loss: 0.1163, Train: 62.86%, Valid: 23.20% Test: 27.40%
# Epoch: 47, Loss: 0.7229, Train: 63.57%, Valid: 21.60% Test: 25.80%
# Epoch: 48, Loss: 0.0038, Train: 65.00%, Valid: 21.00% Test: 25.20%
# Epoch: 49, Loss: 0.0001, Train: 65.00%, Valid: 20.60% Test: 24.90%
# Epoch: 50, Loss: 3.0570, Train: 64.29%, Valid: 20.20% Test: 24.50%
# Epoch: 51, Loss: 0.5013, Train: 67.86%, Valid: 20.60% Test: 25.20%
# Epoch: 52, Loss: 0.5159, Train: 68.57%, Valid: 20.80% Test: 25.80%
# Epoch: 53, Loss: 0.1749, Train: 70.71%, Valid: 21.00% Test: 26.10%
# Epoch: 54, Loss: 0.0737, Train: 72.14%, Valid: 21.80% Test: 26.80%
# Epoch: 55, Loss: 0.1479, Train: 73.57%, Valid: 21.00% Test: 26.30%
# Epoch: 56, Loss: 0.2404, Train: 74.29%, Valid: 21.00% Test: 24.50%
# Epoch: 57, Loss: 0.6847, Train: 74.29%, Valid: 22.20% Test: 26.40%
# Epoch: 58, Loss: 0.1037, Train: 73.57%, Valid: 22.20% Test: 27.20%
# Epoch: 59, Loss: 0.0587, Train: 74.29%, Valid: 22.60% Test: 27.60%
# Epoch: 60, Loss: 0.0787, Train: 73.57%, Valid: 23.20% Test: 27.80%
# Epoch: 61, Loss: 0.0001, Train: 72.14%, Valid: 23.60% Test: 28.90%
# Epoch: 62, Loss: 0.0226, Train: 72.14%, Valid: 24.20% Test: 29.10%
# Epoch: 63, Loss: 0.0198, Train: 72.86%, Valid: 23.40% Test: 29.60%
# Epoch: 64, Loss: 0.4663, Train: 72.86%, Valid: 23.80% Test: 29.80%
# Epoch: 65, Loss: 1.5749, Train: 72.86%, Valid: 23.80% Test: 29.80%
# Epoch: 66, Loss: 0.3390, Train: 72.86%, Valid: 24.20% Test: 30.30%
# Epoch: 67, Loss: 0.3807, Train: 73.57%, Valid: 24.40% Test: 30.60%
# Epoch: 68, Loss: 0.0559, Train: 73.57%, Valid: 25.00% Test: 30.50%
# Epoch: 69, Loss: 0.0168, Train: 74.29%, Valid: 25.40% Test: 30.60%
# Epoch: 70, Loss: 1.4436, Train: 75.71%, Valid: 25.20% Test: 30.70%
# Epoch: 71, Loss: 0.6674, Train: 77.14%, Valid: 25.40% Test: 30.10%
# Epoch: 72, Loss: 0.2357, Train: 77.14%, Valid: 25.80% Test: 29.80%
# Epoch: 73, Loss: 0.2848, Train: 77.14%, Valid: 25.80% Test: 29.80%
# Epoch: 74, Loss: 0.0358, Train: 77.86%, Valid: 26.20% Test: 29.70%
# Epoch: 75, Loss: 0.0596, Train: 77.14%, Valid: 26.20% Test: 30.00%
# Epoch: 76, Loss: 1.1163, Train: 78.57%, Valid: 26.20% Test: 29.70%
# Epoch: 77, Loss: 1.3957, Train: 79.29%, Valid: 25.60% Test: 29.60%
# Epoch: 78, Loss: 0.0999, Train: 79.29%, Valid: 25.20% Test: 29.50%
# Epoch: 79, Loss: 0.2152, Train: 81.43%, Valid: 25.20% Test: 29.80%
# Epoch: 80, Loss: 1.3577, Train: 86.43%, Valid: 24.80% Test: 29.50%
# Epoch: 81, Loss: 0.0414, Train: 87.86%, Valid: 24.60% Test: 29.10%
# Epoch: 82, Loss: 0.0006, Train: 87.86%, Valid: 25.20% Test: 29.20%
# Epoch: 83, Loss: 0.0053, Train: 87.86%, Valid: 24.60% Test: 28.90%
# Epoch: 84, Loss: 0.8807, Train: 88.57%, Valid: 24.60% Test: 28.00%
# Epoch: 85, Loss: 0.0187, Train: 89.29%, Valid: 25.40% Test: 28.10%
# Epoch: 86, Loss: 0.2557, Train: 90.00%, Valid: 26.20% Test: 27.90%
# Epoch: 87, Loss: 0.6487, Train: 90.00%, Valid: 25.80% Test: 27.10%
# Epoch: 88, Loss: 0.1028, Train: 89.29%, Valid: 25.20% Test: 27.10%
# Epoch: 89, Loss: 0.0240, Train: 89.29%, Valid: 24.40% Test: 26.70%
# Epoch: 90, Loss: 0.0001, Train: 89.29%, Valid: 25.00% Test: 26.80%
# Epoch: 91, Loss: 1.1103, Train: 90.00%, Valid: 25.00% Test: 24.60%
# Epoch: 92, Loss: 0.1234, Train: 89.29%, Valid: 23.80% Test: 23.30%
# Epoch: 93, Loss: 0.0261, Train: 89.29%, Valid: 24.00% Test: 23.00%
# Epoch: 94, Loss: 0.1144, Train: 89.29%, Valid: 23.80% Test: 22.80%
# Epoch: 95, Loss: 0.0757, Train: 89.29%, Valid: 23.60% Test: 22.60%
# Epoch: 96, Loss: 0.0917, Train: 89.29%, Valid: 23.60% Test: 21.90%
# Epoch: 97, Loss: 0.0989, Train: 89.29%, Valid: 23.00% Test: 20.90%
# Epoch: 98, Loss: 2.7455, Train: 89.29%, Valid: 22.40% Test: 21.00%
# Epoch: 99, Loss: 0.0253, Train: 89.29%, Valid: 23.20% Test: 21.70%
# Epoch: 100, Loss: 0.1587, Train: 89.29%, Valid: 25.20% Test: 22.20%
# Epoch: 101, Loss: 0.5621, Train: 89.29%, Valid: 26.20% Test: 23.50%
# Epoch: 102, Loss: 0.4188, Train: 90.00%, Valid: 26.80% Test: 24.60%
# Epoch: 103, Loss: 0.0091, Train: 90.71%, Valid: 26.60% Test: 24.80%
# Epoch: 104, Loss: 0.0059, Train: 90.71%, Valid: 27.00% Test: 25.70%
# Epoch: 105, Loss: 0.0073, Train: 90.71%, Valid: 27.00% Test: 26.30%
# Epoch: 106, Loss: 0.0209, Train: 90.00%, Valid: 27.60% Test: 27.70%
# Epoch: 107, Loss: 0.0081, Train: 90.00%, Valid: 26.40% Test: 27.90%
# Epoch: 108, Loss: 0.4862, Train: 90.00%, Valid: 26.40% Test: 27.50%
# Epoch: 109, Loss: 0.0003, Train: 90.00%, Valid: 27.60% Test: 28.70%
# Epoch: 110, Loss: 0.0000, Train: 90.00%, Valid: 27.80% Test: 29.00%
# Epoch: 111, Loss: 0.0000, Train: 89.29%, Valid: 28.20% Test: 29.20%
# Epoch: 112, Loss: 0.0005, Train: 88.57%, Valid: 27.80% Test: 28.90%
# Epoch: 113, Loss: 0.1220, Train: 88.57%, Valid: 28.40% Test: 29.10%
# Epoch: 114, Loss: 0.0011, Train: 88.57%, Valid: 28.40% Test: 29.40%
# Epoch: 115, Loss: 0.0116, Train: 88.57%, Valid: 28.60% Test: 29.10%
# Epoch: 116, Loss: 0.1000, Train: 88.57%, Valid: 28.60% Test: 29.30%
# Epoch: 117, Loss: 0.1656, Train: 88.57%, Valid: 28.60% Test: 29.40%
# Epoch: 118, Loss: 0.2641, Train: 88.57%, Valid: 29.00% Test: 28.80%
# Epoch: 119, Loss: 0.0180, Train: 88.57%, Valid: 28.40% Test: 28.40%
# Epoch: 120, Loss: 0.1087, Train: 89.29%, Valid: 28.60% Test: 29.20%
# Epoch: 121, Loss: 0.0004, Train: 89.29%, Valid: 29.20% Test: 29.50%
# Epoch: 122, Loss: 0.0009, Train: 89.29%, Valid: 29.00% Test: 30.00%
# Epoch: 123, Loss: 0.0633, Train: 89.29%, Valid: 29.40% Test: 30.40%
# Epoch: 124, Loss: 0.0391, Train: 89.29%, Valid: 29.60% Test: 30.80%
# Epoch: 125, Loss: 0.0549, Train: 88.57%, Valid: 29.80% Test: 31.20%
# Epoch: 126, Loss: 0.0000, Train: 89.29%, Valid: 30.00% Test: 31.60%
# Epoch: 127, Loss: 0.0535, Train: 89.29%, Valid: 30.00% Test: 31.80%
# Epoch: 128, Loss: 0.1828, Train: 89.29%, Valid: 30.00% Test: 31.30%
# Epoch: 129, Loss: 0.0017, Train: 89.29%, Valid: 30.00% Test: 31.40%
# Epoch: 130, Loss: 0.2321, Train: 89.29%, Valid: 29.80% Test: 29.60%
# Epoch: 131, Loss: 0.1677, Train: 89.29%, Valid: 30.00% Test: 30.00%
# Epoch: 132, Loss: 0.0011, Train: 90.00%, Valid: 30.20% Test: 30.90%
# Epoch: 133, Loss: 0.0010, Train: 90.00%, Valid: 30.00% Test: 30.90%
# Epoch: 134, Loss: 0.0361, Train: 90.00%, Valid: 29.20% Test: 30.50%
# Epoch: 135, Loss: 0.0508, Train: 90.00%, Valid: 30.20% Test: 30.50%
# Epoch: 136, Loss: 0.0220, Train: 90.00%, Valid: 30.20% Test: 30.30%
# Epoch: 137, Loss: 0.0198, Train: 90.00%, Valid: 29.40% Test: 30.60%
# Epoch: 138, Loss: 0.2756, Train: 90.00%, Valid: 29.80% Test: 30.60%
# Epoch: 139, Loss: 0.0203, Train: 90.00%, Valid: 30.00% Test: 30.80%
# Epoch: 140, Loss: 0.0004, Train: 90.00%, Valid: 31.20% Test: 31.40%
# Epoch: 141, Loss: 0.0166, Train: 90.00%, Valid: 32.00% Test: 31.60%
# Epoch: 142, Loss: 0.0815, Train: 90.00%, Valid: 31.80% Test: 31.40%
# Epoch: 143, Loss: 0.0186, Train: 90.71%, Valid: 32.00% Test: 31.40%
# Epoch: 144, Loss: 0.5033, Train: 90.71%, Valid: 30.60% Test: 30.70%
# Epoch: 145, Loss: 0.0001, Train: 90.71%, Valid: 31.40% Test: 30.90%
# Epoch: 146, Loss: 0.0002, Train: 90.71%, Valid: 31.80% Test: 31.00%
# Epoch: 147, Loss: 0.0033, Train: 90.71%, Valid: 31.80% Test: 31.10%
# Epoch: 148, Loss: 0.3225, Train: 90.71%, Valid: 32.40% Test: 30.60%
# Epoch: 149, Loss: 0.0137, Train: 90.71%, Valid: 31.80% Test: 30.50%
# Epoch: 150, Loss: 0.2624, Train: 90.71%, Valid: 31.60% Test: 30.40%
# Best model: Train: 90.71%, Valid: 32.40% Test: 30.60%

# %% [markdown]
# ## Full-Batch Training

# %%
graphs_train, graphs_val, graphs_test = \
    GraphDataset.pyg_to_graphs(pyg_dataset, verbose=True, fixed_split=True)

graph_train = graphs_train[0]
graph_val = graphs_val[0]
graph_test = graphs_test[0]

model = GNN(graph_train.num_node_features, args['hidden_size'], graph_train.num_node_labels, args).to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'])
graphs = [graph_train, graph_val, graph_test]
all_best_model, all_accs = train(graphs, graphs, args, model, optimizer, mode="all")
train_acc, val_acc, test_acc = test([graph_train, graph_val, graph_test], all_best_model)
print('Best model:',
      f'Train: {100 * train_acc:.2f}%, '
      f'Valid: {100 * val_acc:.2f}% '
      f'Test: {100 * test_acc:.2f}%')
# Out:
# Index fields: val_mask ignored.
# Index fields: test_mask ignored.
# Index fields: train_mask ignored.
# Epoch: 01, Loss: 2.0395, Train: 45.71%, Valid: 22.80% Test: 23.30%
# Epoch: 02, Loss: 1.2012, Train: 87.14%, Valid: 34.00% Test: 33.80%
# Epoch: 03, Loss: 0.6091, Train: 98.57%, Valid: 47.00% Test: 48.20%
# Epoch: 04, Loss: 0.3503, Train: 100.00%, Valid: 53.20% Test: 56.40%
# Epoch: 05, Loss: 0.1712, Train: 100.00%, Valid: 62.00% Test: 61.60%
# Epoch: 06, Loss: 0.0718, Train: 100.00%, Valid: 66.60% Test: 67.50%
# Epoch: 07, Loss: 0.0342, Train: 100.00%, Valid: 70.00% Test: 69.90%
# Epoch: 08, Loss: 0.0234, Train: 100.00%, Valid: 71.80% Test: 72.00%
# Epoch: 09, Loss: 0.0196, Train: 100.00%, Valid: 71.60% Test: 72.90%
# Epoch: 10, Loss: 0.0074, Train: 100.00%, Valid: 73.60% Test: 74.20%
# Epoch: 11, Loss: 0.0058, Train: 100.00%, Valid: 73.00% Test: 74.40%
# Epoch: 12, Loss: 0.0038, Train: 100.00%, Valid: 72.80% Test: 74.60%
# Epoch: 13, Loss: 0.0016, Train: 100.00%, Valid: 72.80% Test: 74.40%
# Epoch: 14, Loss: 0.0017, Train: 100.00%, Valid: 73.40% Test: 74.70%
# Epoch: 15, Loss: 0.0013, Train: 100.00%, Valid: 73.20% Test: 74.70%
# Epoch: 16, Loss: 0.0014, Train: 100.00%, Valid: 72.80% Test: 74.60%
# Epoch: 17, Loss: 0.0005, Train: 100.00%, Valid: 73.20% Test: 74.70%
# Epoch: 18, Loss: 0.0016, Train: 100.00%, Valid: 73.20% Test: 74.90%
# Epoch: 19, Loss: 0.0009, Train: 100.00%, Valid: 72.80% Test: 75.00%
# Epoch: 20, Loss: 0.0011, Train: 100.00%, Valid: 73.00% Test: 75.20%
# Epoch: 21, Loss: 0.0003, Train: 100.00%, Valid: 73.60% Test: 75.40%
# Epoch: 22, Loss: 0.0003, Train: 100.00%, Valid: 73.60% Test: 75.30%
# Epoch: 23, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.40%
# Epoch: 24, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 75.20%
# Epoch: 25, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 75.50%
# Epoch: 26, Loss: 0.0002, Train: 100.00%, Valid: 73.60% Test: 75.50%
# Epoch: 27, Loss: 0.0001, Train: 100.00%, Valid: 73.40% Test: 75.60%
# Epoch: 28, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 75.60%
# Epoch: 29, Loss: 0.0005, Train: 100.00%, Valid: 73.60% Test: 75.50%
# Epoch: 30, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 75.40%
# Epoch: 31, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 75.50%
# Epoch: 32, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 75.40%
# Epoch: 33, Loss: 0.0000, Train: 100.00%, Valid: 73.60% Test: 75.30%
# Epoch: 34, Loss: 0.0002, Train: 100.00%, Valid: 73.60% Test: 75.40%
# Epoch: 35, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 75.60%
# Epoch: 36, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 75.70%
# Epoch: 37, Loss: 0.0000, Train: 100.00%, Valid: 73.60% Test: 75.70%
# Epoch: 38, Loss: 0.0001, Train: 100.00%, Valid: 73.60% Test: 75.70%
# Epoch: 39, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 75.80%
# Epoch: 40, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 75.70%
# Epoch: 41, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 75.70%
# Epoch: 42, Loss: 0.0000, Train: 100.00%, Valid: 73.40% Test: 75.80%
# Epoch: 43, Loss: 0.0002, Train: 100.00%, Valid: 73.40% Test: 75.80%
# Epoch: 44, Loss: 0.0000, Train: 100.00%, Valid: 73.20% Test: 75.80%
# Epoch: 45, Loss: 0.0008, Train: 100.00%, Valid: 73.20% Test: 75.80%
# Epoch: 46, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 75.80%
# Epoch: 47, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 75.80%
# Epoch: 48, Loss: 0.0001, Train: 100.00%, Valid: 73.00% Test: 75.70%
# Epoch: 49, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 75.70%
# Epoch: 50, Loss: 0.0002, Train: 100.00%, Valid: 72.80% Test: 75.50%
# Epoch: 51, Loss: 0.0003, Train: 100.00%, Valid: 72.80% Test: 75.40%
# Epoch: 52, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 75.20%
# Epoch: 53, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 75.20%
# Epoch: 54, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 75.20%
# Epoch: 55, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 56, Loss: 0.0002, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 57, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.10%
# Epoch: 58, Loss: 0.0002, Train: 100.00%, Valid: 72.40% Test: 75.10%
# Epoch: 59, Loss: 0.0007, Train: 100.00%, Valid: 72.40% Test: 75.00%
# Epoch: 60, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.00%
# Epoch: 61, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.00%
# Epoch: 62, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.00%
# Epoch: 63, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.00%
# Epoch: 64, Loss: 0.0002, Train: 100.00%, Valid: 72.60% Test: 75.00%
# Epoch: 65, Loss: 0.0002, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 66, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 67, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 68, Loss: 0.0000, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 69, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 70, Loss: 0.0000, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 71, Loss: 0.0001, Train: 100.00%, Valid: 72.60% Test: 75.10%
# Epoch: 72, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.10%
# Epoch: 73, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 74, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 75, Loss: 0.0003, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 76, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 77, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 78, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 79, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 80, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 81, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 82, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 83, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 84, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 85, Loss: 0.0002, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 86, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 87, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 88, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 89, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 90, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 91, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 92, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 93, Loss: 0.0007, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 94, Loss: 0.0003, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 95, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 96, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 97, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 98, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 99, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 100, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 101, Loss: 0.0005, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 102, Loss: 0.0002, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 103, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 104, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 105, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 106, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 107, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 108, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.20%
# Epoch: 109, Loss: 0.0001, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 110, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.30%
# Epoch: 111, Loss: 0.0035, Train: 100.00%, Valid: 72.20% Test: 75.50%
# Epoch: 112, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.50%
# Epoch: 113, Loss: 0.0000, Train: 100.00%, Valid: 72.60% Test: 75.60%
# Epoch: 114, Loss: 0.0000, Train: 100.00%, Valid: 72.60% Test: 75.60%
# Epoch: 115, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 75.50%
# Epoch: 116, Loss: 0.0001, Train: 100.00%, Valid: 72.80% Test: 75.40%
# Epoch: 117, Loss: 0.0000, Train: 100.00%, Valid: 72.80% Test: 75.40%
# Epoch: 118, Loss: 0.0001, Train: 100.00%, Valid: 72.80% Test: 75.30%
# Epoch: 119, Loss: 0.0015, Train: 100.00%, Valid: 72.80% Test: 75.30%
# Epoch: 120, Loss: 0.0000, Train: 100.00%, Valid: 72.40% Test: 75.40%
# Epoch: 121, Loss: 0.0000, Train: 100.00%, Valid: 72.20% Test: 75.40%
# Epoch: 122, Loss: 0.0001, Train: 100.00%, Valid: 72.20% Test: 75.50%
# Epoch: 123, Loss: 0.0000, Train: 100.00%, Valid: 72.00% Test: 75.40%
# Epoch: 124, Loss: 0.0000, Train: 100.00%, Valid: 72.00% Test: 75.40%
# Epoch: 125, Loss: 0.0006, Train: 100.00%, Valid: 72.00% Test: 75.50%
# Epoch: 126, Loss: 0.0001, Train: 100.00%, Valid: 72.00% Test: 75.50%
# Epoch: 127, Loss: 0.0002, Train: 100.00%, Valid: 71.80% Test: 75.50%
# Epoch: 128, Loss: 0.0000, Train: 100.00%, Valid: 71.80% Test: 75.50%
# Epoch: 129, Loss: 0.0019, Train: 100.00%, Valid: 72.00% Test: 75.40%
# Epoch: 130, Loss: 0.0000, Train: 100.00%, Valid: 71.40% Test: 75.40%
# Epoch: 131, Loss: 0.0001, Train: 100.00%, Valid: 71.60% Test: 75.40%
# Epoch: 132, Loss: 0.0002, Train: 100.00%, Valid: 71.40% Test: 75.30%
# Epoch: 133, Loss: 0.0001, Train: 100.00%, Valid: 71.40% Test: 75.30%
# Epoch: 134, Loss: 0.0000, Train: 100.00%, Valid: 71.40% Test: 75.20%
# Epoch: 135, Loss: 0.0000, Train: 100.00%, Valid: 71.40% Test: 75.10%
# Epoch: 136, Loss: 0.0001, Train: 100.00%, Valid: 71.40% Test: 75.00%
# Epoch: 137, Loss: 0.0000, Train: 100.00%, Valid: 71.20% Test: 75.00%
# Epoch: 138, Loss: 0.0000, Train: 100.00%, Valid: 71.40% Test: 75.00%
# Epoch: 139, Loss: 0.0011, Train: 100.00%, Valid: 71.20% Test: 75.10%
# Epoch: 140, Loss: 0.0000, Train: 100.00%, Valid: 71.20% Test: 75.10%
# Epoch: 141, Loss: 0.0000, Train: 100.00%, Valid: 71.20% Test: 75.20%
# Epoch: 142, Loss: 0.0000, Train: 100.00%, Valid: 71.20% Test: 75.20%
# Epoch: 143, Loss: 0.0000, Train: 100.00%, Valid: 71.20% Test: 75.20%
# Epoch: 144, Loss: 0.0000, Train: 100.00%, Valid: 71.20% Test: 75.20%
# Epoch: 145, Loss: 0.0003, Train: 100.00%, Valid: 71.40% Test: 75.10%
# Epoch: 146, Loss: 0.0008, Train: 100.00%, Valid: 71.40% Test: 75.20%
# Epoch: 147, Loss: 0.0004, Train: 100.00%, Valid: 71.40% Test: 75.30%
# Epoch: 148, Loss: 0.0000, Train: 100.00%, Valid: 71.60% Test: 75.30%
# Epoch: 149, Loss: 0.0000, Train: 100.00%, Valid: 71.40% Test: 75.30%
# Epoch: 150, Loss: 0.0000, Train: 100.00%, Valid: 71.20% Test: 75.30%
# Best model: Train: 100.00%, Valid: 73.60% Test: 74.20%

# %% [markdown]
# ## Visualization

# %%
import numpy as np
from matplotlib import pyplot as plt

louvain_results = np.array(louvain_accs)
bisection_results = np.array(bisection_accs)
greedy_results = np.array(greedy_accs)
all_results = np.array(all_accs)

x = np.arange(1, 151)

plt.figure(figsize=(9, 7))

plt.plot(x, louvain_results[:, 1], label="Louvain Validation")
plt.plot(x, louvain_results[:, 2], label="Louvain Test")
plt.plot(x, bisection_results[:, 1], label="Bisection Validation")
plt.plot(x, bisection_results[:, 2], label="Bisection Test")
plt.plot(x, greedy_results[:, 1], label="Greedy Validation")
plt.plot(x, greedy_results[:, 2], label="Greedy Test")
plt.plot(x, all_results[:, 1], label="All Validation")
plt.plot(x, all_results[:, 2], label="All Test")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
